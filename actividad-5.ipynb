# %% [markdown]
# # Predicción de nacimientos en Colombia
#
# ## Participantes
# - Bechara, Hermes (hacordoba77@unisalle.edu.co)
# - Liscano, Andrés (aliscano20@unisalle.edu.co)
# - Montealegre, Efrain (emontealegre19@unisalle.edu.co)

# %% [markdown]
# # Introducción
# Este proyecto tiene como propósito desarrollar un modelo de Machine Learning capaz de predecir las tasas de natalidad en Colombia, utilizando datos históricos proporcionados por el DANE. La capacidad de predecir nacimientos es crucial para la planificación de políticas públicas en áreas como la salud, la educación y la infraestructura, así como para la toma de decisiones estratégicas en diversos sectores.
#
# El modelo se construirá a partir de un análisis exhaustivo de los datos de nacimientos, identificando patrones y factores que influyen en la natalidad. Se utilizarán técnicas de preprocesamiento, exploración de datos, selección de modelos, entrenamiento y evaluación para asegurar la robustez y precisión de las predicciones.
#
# ## Principales librerías utilizadas:
#
# - pandas: Para la manipulación y análisis de datos estructurados.
# - numpy: Para operaciones numéricas eficientes, especialmente con arreglos.
# - matplotlib.pyplot: Para la creación de visualizaciones estáticas y dinámicas.
# - seaborn: Basado en matplotlib, para crear gráficos estadísticos atractivos e informativos.
# - sklearn (scikit-learn): Una librería completa para Machine Learning, incluyendo herramientas para preprocesamiento, selección de modelos, entrenamiento y evaluación.
#
# ## Datos utilizados:
#
# Se utilizarán los siguientes archivos CSV, que contienen datos de nacimientos en Colombia para los años 2020, 2021, 2022 y 2023:
# - [Estadísticas Vitales - EEVV – 2020](https://microdatos.dane.gov.co/index.php/catalog/732)
# - [Estadísticas Vitales - EEVV – 2021](https://microdatos.dane.gov.co/index.php/catalog/775)
# - [Estadísticas Vitales - EEVV – 2022](https://microdatos.dane.gov.co/index.php/catalog/807)
# - [Estadísticas Vitales - EEVV – 2023](https://microdatos.dane.gov.co/index.php/catalog/843)
#
# >Fuente: Departamento Administrativo Nacional de Estadística: www.dane.gov.co. Queda en cambio prohibida la copia o reproducción de los datos en cualquier medio electrónico (redes, bases de datos, cd rom, diskettes) que permita la disponibilidad de esta información a múltiples usuarios sin el previo visto bueno del DANE por medio escrito.

# %% [markdown]
# ## Variables DANE
#
# Descripción general de las variables obtenidas de los microdatos del DANE. [Ver el diccionario de datos completo](#diccionario-de-datos-de-variables-dane)
#
# | Variable | Etiqueta | Concepto |
# |----------|----------|----------|
# | COD_DPTO | Departamento de Nacimiento | Departamento de Nacimiento<br><br>Código, según la División Político- Administrativa del DANE.<br><br>05= Antioquia<br>08= Atlántico<br>11= Bogotá<br>13= Bolivar<br>15= Boyaca<br>17=Caldas<br>18= Caqueta<br>19=Cauca<br>20= Cesar<br>23= Cordoba<br>25=Cundinamarca<br>27= Choco<br>41= Huila<br>44= La guajira<br>47= Magdalena<br>50= Meta<br>52= Nariño<br>54= Norte de Santander<br>63= Quindio<br>66= Risaralda<br>68= Santander<br>70= Sucre<br>73= Tolima<br>76= Valle del Cauca<br>81= Arauca<br>85= Casanare<br>86= Putumayo<br>88= Archipiélago de San Andrés, Providencia y Santa Catalina<br>91= Amazonas<br>94= Guainía<br>95= Guaviare<br>97= Vaupés<br>99= Vichada |
# | COD_MUNIC | Municipio de Nacimiento | Municipio de Nacimiento<br><br>Código, según la División Político- Administrativa del DANE. |
# | AREANAC | Área del Nacimiento | Área del Nacimiento<br><br>1 = Cabecera municipal                                                                                        <br>2 = Centro poblado (Inspección, corregimiento o caserío)                                                                         <br>3 = Rural disperso                                                                    <br>9 = Sin información |
# | SIT_PARTO | Sitio de la Parto | Sitio de la Parto<br><br>1 = Institución de salud    <br>2 = Domicilio<br>3 = Otro<br>9 = Sin información |
# | OTRO_SIT | Otro sitio, ¿cuál? | Otro sitio, ¿cuál? |
# | SEXO | Sexo del nacido vivo | Sexo del nacido vivo<br><br>1 = Masculino<br>2 = Femenino <br>3= Indeterminado |
# | PESO_NAC | Peso del nacido vivo, al nacer | Peso del nacido vivo, al nacer <br><br>1 =  Menos de 1.000<br>2 = 1.000 - 1.499<br>3 = 1.500 - 1.999 <br>4 = 2.000 - 2499<br>5 = 2.500 - 2.999<br>6 = 3.000 - 3499<br>7 = 3.500 - 3.999<br>8 = 4.000 y más<br>9 = Sin información |
# | TALLA_NAC | Talla del nacido vivo, al nacer | Talla del nacido vivo, al nacer <br><br> 1 = Menos de 20<br> 2 = 20-29<br> 3 = 30-39<br> 4 = 40-49<br> 5 = 50-59<br> 6 = 60 y Más.<br> 9 = Sin información |
# | ANO | Año de la ocurrencia | Año de la ocurrencia<br><br>2023 |
# | MES | Mes de la ocurrencia | Mes de la ocurrencia<br><br>01 = Enero<br>02 = Febrero<br>03 = Marzo<br>04 = Abril<br>05 = Mayo<br>06 = Junio<br>07 = Julio<br>08 = Agosto<br>09 = Septiembre<br>10 = Octubre<br>11 = Noviembre<br>12 = Diciembre |
# | ATEN_PAR | El parto fue atendido por | El parto fue atendido por<br><br>1 = Médico  <br>2 = Enfermero(a) <br>3 = Auxiliar de enfermería<br>4 = Promotor(a) de salud  <br>5 = Partera <br>6 = Otro persona <br>9 = Sin información |
# | T_GES | Tiempo de gestación del nacido vivo | Tiempo de gestación del nacido vivo<br><br> 1 = Menos de 22<br> 2 = De 22 a 27<br> 3 = De 28 a 37<br> 4 = De 38 a 41<br> 5 = De 42 y más <br> 6 = Ignorado<br> 9 = Sin información |
# | T_GES_AGRU_CIE | Tiempo de gestación del nacido vivo ajustado a la agrupación sugerida por la CIE | Tiempo de gestación del nacido vivo ajustado a la agrupación sugerida por la CIE<br><br> 1 = Menos de 22<br> 2 = De 22 a 27<br> 3 = De 28 a 36<br> 4 = De 37 a 41<br> 5 = De 42 y más <br> 6 = Ignorado<br> 9 = Sin información |
# | NUMCONSUL | Número de consultas prenatales que tuvo la madre del nacido vivo | Número de consultas prenatales que tuvo la madre del nacido vivo<br><br>00= Ninguna<br>99 = Sin información |
# | TIPO_PARTO | Tipo de parto de este nacimiento | Tipo de parto de este nacimiento<br><br>1 = Espontáneo             <br>2 = Cesárea<br>3 = Instrumentado<br>4 = Ignorado <br>9 = Sin información |
# | MUL_PARTO | Multiplicidad del embarazo | Multiplicidad del embarazo<br><br>1 = Simple           <br>2 = Doble<br>3 = Triple<br>4 = Cuádruple o más <br>9 = Sin información |
# | APGAR1 | APGAR al minuto del nacido vivo | APGAR al minuto del nacido vivo<br><br>01 - 10 = Al minuto<br>99 = sin información |
# | APGAR2 | APGAR a los cinco minutos del nacido vivo | APGAR a los cinco minutos del nacido vivo<br><br>01 - 10 = A los cinco minutos<br>99 = sin información |
# | IDHEMOCLAS | Hemoclasificación del nacido vivo: Grupo Sanguíneo | Hemoclasificación del nacido vivo: Grupo Sanguíneo<br><br>1 = A    <br>2 = B<br>3 = O<br>4 = AB                                                                                                                 <br>9 = Sin información |
# | IDFACTORRH | Hemoclasificación del nacido vivo:   Factor RH | Hemoclasificación del nacido vivo:  Factor RH<br><br>1 = Positivo  <br>2 = Negativo<br>9= Sin información |
# | IDPERTET | De acuerdo con la cultura, pueblo o rasgos físicos, el nacido vivo es reconocido por sus padres como | De acuerdo con la cultura, pueblo o rasgos físicos, el nacido vivo es reconocido por sus padres como<br><br>1 = Indígena                                                  <br>2 = Rom (Gitano)                                                                     <br>3 = Raizal del archipiélago de San Andrés y Providencia                                                                  <br>4 = Palenquero de San Basilio         <br>5 = Negro(a), mulato(a), afrocolombiano(a) o afrodescendiente                                                                   <br>6 = Ninguna de las anteriores  <br>9 = Sin información |
# | EDAD_MADRE | Edad de la madre a la fecha del parto | Edad de la madre a la fecha del parto<br><br>1 = De 10-14 Años<br>2 = De 15-19 Años<br>3 = De 20-24 Años<br>4 = De 25-29 Años<br>5 = De 30-34 Años<br>6 = De 35-39 Años<br>7 = De 40-44 Años<br>8 = De 45-49 Años<br>9 = De 50-54 Años<br>99 = Sin información |
# | EST_CIVM | Estado conyugal de la madre | Estado conyugal de la madre<br><br>1 = No está casada y lleva dos o más años viviendo con su pareja<br>2 = No está casada y lleva menos de dos años viviendo con su pareja                                                                                      <br>3 = Está separada, divorciada       <br>4 = Está viuda                                    <br>5 = Está soltera <br>6 = Está casada<br>9 = Sin información |
# | NIV_EDUM | Ultimo nivel de estudio que aprobó la madre | Nivel educativo del la madre       <br><br>1 = Preescolar<br>2 = Básica primaria<br>3 = Básica secundaria <br>4 = Media académica o clásica <br>5 = Media técnica <br>6 = Normalista<br>7 = Técnica profesional  <br>8 = Tecnológica<br>9 = Profesional<br>10 = Especialización<br>11 = Maestría<br>12 = Doctorado                                                                                    <br>13 = Ninguno       <br>99 = Sin información |
# | ULTCURMAD | Ultimo año o grado aprobado de la madre | Ultimo año o grado aprobado de la madre<br><br>99 = Sin información. |
# | CODPRES | País de residencia habitual de la madre en el extranjero | País de residencia habitual de la madre en el extranjero<br><br>Código, según listado de países  ISO 3166/2 |
# | CODPTORE | Departamento de residencia habitual de la madre | Departamento de residencia habitual de la madre<br><br>Código, según la División Político- Administrativa del DANE. |
# | CODMUNRE | Municipio de residencia habitual de la madre | Municipio de residencia habitual de la madre<br><br>Municipio de residencia habitual, según la División Político- Administrativa del DANE |
# | AREA_RES | Área de residencia habitual de la madre | Área de residencia habitual de la madre<br><br>1 = Cabecera municipal    <br>2 = Centro poblado (inspección, corregimiento o caserío)                                                                     <br>3 = Rural disperso   <br>9 = Sin información |
# | N_HIJOSV | Número de hijos nacidos vivos que ha tenido la madre, incluido el presente | Número de hijos nacidos vivos que ha tenido la madre, incluido el presente<br><br> 1 = 1 hijo<br> 2 = 2 hijos<br> 3 = 3 hijos<br> 4 = 4 hijos<br> 5 = 5 hijos<br> 6 = 6 hijos<br> 7 = 7 hijos<br> 8 = 8 hijos<br> 9 = 9 hijos<br> 10 = 10 hijos<br> 11 = 11 hijos<br> 12 = 12 hijos<br> 13 = 13 hijos<br> 14 = 14 hijos<br> 15 = 15 hijos<br> 16 = 16 hijos <br> 17 = 17 hijos<br> 18 = 18 hijos<br> 19 = 19 hijos<br> 20 = 20 hijos<br> 21 = 21 hijos<br> 22 = 22 hijos<br> 99 = Sin información |
# | FECHA_NACM | Fecha de nacimiento del anterior hijo nacido vivo | Fecha de nacimiento del anterior hijo nacido vivo |
# | N_EMB | Número de embarazos, incluido el presente | Número de embarazos, incluido el presente<br><br>99 = Sin información |
# | SEG_SOCIAL | Régimen de seguridad social en salud de la madre | Régimen de seguridad social en salud de la madre<br><br>1 = Contributivo            <br>2 = Subsidiado<br>3 = Excepción <br>4 = Especial <br>5 = No asegurado<br>9 = Sin información |
# | IDCLASADMI | Entidad Administradora en Salud a la que pertenece la madre | Entidad Administradora en Salud a la que pertenece la madre<br><br>1 = Entidad promotora de salud                   <br>2 = Entidad promotora de salud - Subsidiado                                                          <br>3 = Entidad adaptada de salud     <br>4 = Entidad especial de salud  <br>5 = Entidad exceptuada de salud       <br>9 = Sin información |
# | EDAD_PADRE | Edad del padre en años cumplidos a la fecha del nacimiento de este hijo | Edad del padre en años cumplidos a la fecha del nacimiento de este hijo<br><br>999 = Sin información |
# | ULTCURPAD | Ultimo año o grado aprobado del padre | Último año o grado aprobado del nivel educativo del padre<br><br>99 = Sin información |
# | PROFESION | Profesión de quien certifica el nacimiento | Profesión de quien certifica el nacimiento<br><br>1 = Médico<br>2 = Enfermero(a) <br>3 = Auxiliar de enfermería<br>4 = Promotor(a) de salud  <br>5 = Funcionario de registro civil<br>9= Sin Información |
# | TIPOFORMULARIO | Fuente del Certificado | Tipo de formulario para la captura de información<br><br>1 = Certificado RUAF-ND<br>2 = Formato de Notificación Étnica<br>3 = Recuperación cruce RNEC |

# %% [markdown]
# # Importación de librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Configuración para visualizaciones
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# %% [markdown]
# # Preprocesamiento de los datos
#
# Esta sección detalla el proceso de carga, combinación y limpieza de los datos de nacimientos. Es fundamental preparar los datos adecuadamente para asegurar la calidad y fiabilidad del modelo de Machine Learning.

# %%
# Rutas de los archivos CSV
file_paths = {
    '2020': './data/nac2020.csv',
    '2021': './data/nac2021.csv',
    '2022': './data/nac2022.csv',
    '2023': './data/BD-EEVV-Nacimientos-2023.csv'
}

# Lista para almacenar los DataFrames individuales
dfs = []

# Cargar cada archivo CSV
for year, path in file_paths.items():
    try:
        # Intentar leer con codificación 'latin1' (común en archivos de datos de Latinoamérica)
        df = pd.read_csv(path, encoding='latin1', low_memory=False)
        dfs.append(df)
        print(f"Cargado {path} con {len(df)} filas.")
    except FileNotFoundError:
        print(f"Error: El archivo {path} no fue encontrado. Asegúrate de que está en la misma carpeta.")
    except UnicodeDecodeError:
        print(f"Error de decodificación Unicode para {path}. Intentando con otra codificación o revisa el archivo.")
    except Exception as e:
        print(f"Error al cargar {path}: {e}")

# Concatenar todos los DataFrames en uno solo
if dfs:
    df_combined = pd.concat(dfs, ignore_index=True)
    print(f"\nTotal de filas combinadas: {len(df_combined)}")
else:
    df_combined = pd.DataFrame()
    print("No se pudo cargar ningún archivo CSV.")

# Mostrar las primeras filas del DataFrame combinado
print("\nPrimeras 5 filas del DataFrame combinado:")
df_combined.head()
# Out:
# Cargado ./data/nac2020.csv con 629402 filas.
# Cargado ./data/nac2021.csv con 616914 filas.
# Cargado ./data/nac2022.csv con 573625 filas.
# Cargado ./data/BD-EEVV-Nacimientos-2023.csv con 515549 filas.
#
# Total de filas combinadas: 2335490
#
# Primeras 5 filas del DataFrame combinado:
#    COD_DPTO  COD_MUNIC  AREANAC  SIT_PARTO OTRO_SIT  SEXO  PESO_NAC  \
# 0        44        560        3          2      NaN     2         9
# 1        44        560        3          2      NaN     1         9
# 2        44        560        3          2      NaN     1         9
# 3        44        560        3          2      NaN     2         9
# 4        44        560        3          2      NaN     2         9
#
#    TALLA_NAC   ANO  MES  ...  FECHA_NACM  N_EMB  SEG_SOCIAL  IDCLASADMI  \
# 0          9  2020   11  ...         NaN      1           2         2.0
# 1          9  2020   10  ...         NaN      1           2         2.0
# 2          9  2020   10  ...         NaN      1           2         2.0
# 3          9  2020    4  ...         NaN      1           2         2.0
# 4          9  2020    8  ...         NaN      1           2         2.0
#
#    EDAD_PADRE  NIV_EDUP  ULTCURPAD  PROFESION  T_GES_AGRU_CIE  TIPOFORMULARIO
# 0          20        99         99        5.0             NaN             NaN
# 1          20        99         99        5.0             NaN             NaN
# 2          20        99         99        5.0             NaN             NaN
# 3          20        99         99        5.0             NaN             NaN
# 4          20        99         99        5.0             NaN             NaN
#
# [5 rows x 39 columns]

# %%
df_combined.describe()
# Out:
#            COD_DPTO     COD_MUNIC       AREANAC     SIT_PARTO          SEXO  \
# count  2.335490e+06  2.335490e+06  2.335490e+06  2.335490e+06  2.335490e+06
# mean   3.429114e+01  1.651475e+02  1.059588e+00  1.045462e+00  1.487766e+00
# std    2.654568e+01  2.624322e+02  4.857132e-01  4.421277e-01  5.000157e-01
# min    5.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.100000e+01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 50%    2.300000e+01  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 75%    5.400000e+01  2.760000e+02  1.000000e+00  1.000000e+00  2.000000e+00
# max    9.900000e+01  9.800000e+02  9.000000e+00  9.000000e+00  3.000000e+00
#
#            PESO_NAC     TALLA_NAC           ANO           MES      ATEN_PAR  \
# count  2.335490e+06  2.335490e+06  2.335490e+06  2.335490e+06  2.335490e+06
# mean   5.714063e+00  4.600660e+00  2.021418e+03  6.566154e+00  1.110525e+00
# std    1.110983e+00  7.156464e-01  1.106206e+00  3.435411e+00  7.314485e-01
# min    1.000000e+00  1.000000e+00  2.020000e+03  1.000000e+00  1.000000e+00
# 25%    5.000000e+00  4.000000e+00  2.020000e+03  4.000000e+00  1.000000e+00
# 50%    6.000000e+00  5.000000e+00  2.021000e+03  7.000000e+00  1.000000e+00
# 75%    6.000000e+00  5.000000e+00  2.022000e+03  1.000000e+01  1.000000e+00
# max    9.000000e+00  9.000000e+00  2.023000e+03  1.200000e+01  9.000000e+00
#
#        ...      N_HIJOSV         N_EMB    SEG_SOCIAL    IDCLASADMI  \
# count  ...  2.335490e+06  2.335490e+06  2.335490e+06  2.133265e+06
# mean   ...  2.211423e+00  2.391091e+00  1.941434e+00  1.683406e+00
# std    ...  5.350110e+00  5.379625e+00  1.134177e+00  7.650982e-01
# min    ...  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    ...  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 50%    ...  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# 75%    ...  2.000000e+00  3.000000e+00  2.000000e+00  2.000000e+00
# max    ...  9.900000e+01  9.900000e+01  9.000000e+00  9.000000e+00
#
#          EDAD_PADRE      NIV_EDUP     ULTCURPAD     PROFESION  T_GES_AGRU_CIE  \
# count  2.335490e+06  2.335490e+06  2.335490e+06  2.328739e+06    1.706088e+06
# mean   4.007108e+01  1.388420e+01  1.653518e+01  1.040221e+00    3.912816e+00
# std    9.863054e+01  2.810221e+01  2.733747e+01  3.785451e-01    4.046033e-01
# min    1.200000e+01  1.000000e+00  0.000000e+00  1.000000e+00    1.000000e+00
# 25%    2.400000e+01  3.000000e+00  5.000000e+00  1.000000e+00    4.000000e+00
# 50%    2.900000e+01  4.000000e+00  9.000000e+00  1.000000e+00    4.000000e+00
# 75%    3.500000e+01  8.000000e+00  1.100000e+01  1.000000e+00    4.000000e+00
# max    9.990000e+02  9.900000e+01  9.900000e+01  5.000000e+00    9.000000e+00
#
#        TIPOFORMULARIO
# count    1.706088e+06
# mean     1.007573e+00
# std      1.214408e-01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      3.000000e+00
#
# [8 rows x 37 columns]

# %% [markdown]
# # Manejo de valores faltantes
#
# Se identificarán las columnas con valores nulos y se aplicará una estrategia de imputación o eliminación según la relevancia de la columna para el modelo y la cantidad de datos faltantes.

# %%
# Información general del DataFrame y conteo de valores nulos
print("\nInformación del DataFrame combinado:")
df_combined.info()

print("\nValores nulos por columna:")
missing_values = df_combined.isnull().sum()
print(missing_values[missing_values > 0].sort_values(ascending=False))

# Estrategia de manejo de nulos:
# 1. 'OTRO_SIT': Tiene muchos nulos y es una descripción específica. No es directamente relevante para la tasa de natalidad general, así que se puede eliminar.
# 2. 'FECHA_NACM': Fecha de nacimiento de la madre. Muchos nulos. Para la predicción de nacimientos por mes/año, no es una variable clave. Se puede eliminar.

# 'OTRO_SIT' y 'FECHA_NACM': Se eliminan por tener muchos nulos y no ser directamente relevantes para la predicción agregada.
columns_to_drop = ['OTRO_SIT', 'FECHA_NACM']
df_processed = df_combined.drop(columns=columns_to_drop, errors='ignore')

print(f"\nColumnas eliminadas: {columns_to_drop}")
print(f"Filas restantes después de eliminar columnas: {len(df_processed)}")

# Estandarización de valores especiales (9 y 99) que indican 'Sin información'
# Se aplicará a columnas numéricas que representan categorías o códigos.
# Se excluyen 'ANO', 'MES', 'PESO_NAC', 'TALLA_NAC', 'EDAD_MADRE', 'EDAD_PADRE',
# ya que 9/99 no tendría sentido como valor faltante en ellas o son medidas directas.
cols_to_standardize = [
    col for col in df_processed.columns
    if df_processed[col].dtype in ['int64', 'float64'] and
    col not in ['ANO', 'MES', 'PESO_NAC', 'TALLA_NAC', 'EDAD_MADRE', 'EDAD_PADRE']
]

for col in cols_to_standardize:
    # Reemplazar 9 y 99 con NaN en las columnas identificadas
    df_processed[col] = df_processed[col].replace({9: np.nan, 99: np.nan})
    # Si la columna era originalmente int, convertirla a float después de introducir NaN
    if df_combined[col].dtype == 'int64': # Usar df_combined para el dtype original
        df_processed[col] = df_processed[col].astype(float)

print("\nValores nulos después de estandarizar 9 y 99:")
missing_values_after_standardization = df_processed.isnull().sum()
print(missing_values_after_standardization[missing_values_after_standardization > 0].sort_values(ascending=False))


# Para el análisis departamental, es crucial que COD_DPTO no tenga nulos.
# Si después de la estandarización hay nulos en COD_DPTO, se eliminarán esas filas.
if df_processed['COD_DPTO'].isnull().any():
    initial_rows = len(df_processed)
    df_processed.dropna(subset=['COD_DPTO'], inplace=True)
    print(f"\nSe eliminaron {initial_rows - len(df_processed)} filas con COD_DPTO nulo.")
    print(f"Filas restantes después de eliminar COD_DPTO nulos: {len(df_processed)}")

# Asegurarse de que COD_DPTO es de tipo entero para la agrupación
df_processed['COD_DPTO'] = df_processed['COD_DPTO'].astype(int)


# Verificar duplicados
print("\nNúmero de filas duplicadas ANTES de eliminar:", df_processed.duplicated().sum())
df_processed.drop_duplicates(inplace=True)
print("Filas después de eliminar duplicados:", len(df_processed))
# Out:
# Información del DataFrame combinado:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2335490 entries, 0 to 2335489
# Data columns (total 39 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   COD_DPTO        int64
#  1   COD_MUNIC       int64
#  2   AREANAC         int64
#  3   SIT_PARTO       int64
#  4   OTRO_SIT        object
#  5   SEXO            int64
#  6   PESO_NAC        int64
#  7   TALLA_NAC       int64
#  8   ANO             int64
#  9   MES             int64
#  10  ATEN_PAR        int64
#  11  T_GES           int64
#  12  NUMCONSUL       int64
#  13  TIPO_PARTO      int64
#  14  MUL_PARTO       int64
#  15  APGAR1          int64
#  16  APGAR2          int64
#  17  IDHEMOCLAS      int64
#  18  IDFACTORRH      int64
#  19  IDPERTET        int64
#  20  EDAD_MADRE      int64
#  21  EST_CIVM        int64
#  22  NIV_EDUM        int64
#  23  ULTCURMAD       int64
#  24  CODPRES         float64
#  25  CODPTORE        float64
#  26  CODMUNRE        float64
#  27  AREA_RES        float64
#  28  N_HIJOSV        int64
#  29  FECHA_NACM      object
#  30  N_EMB           int64
#  31  SEG_SOCIAL      int64
#  32  IDCLASADMI      float64
#  33  EDAD_PADRE      int64
#  34  NIV_EDUP        int64
#  35  ULTCURPAD       int64
#  36  PROFESION       float64
#  37  T_GES_AGRU_CIE  float64
#  38  TIPOFORMULARIO  float64
# dtypes: float64(8), int64(29), object(2)
# memory usage: 694.9+ MB
#
# Valores nulos por columna:
# OTRO_SIT          2330623
# FECHA_NACM        1061732
# T_GES_AGRU_CIE     629402
# TIPOFORMULARIO     629402
# IDCLASADMI         202225
# CODPTORE            32279
# CODMUNRE            32279
# AREA_RES            32265
# PROFESION            6751
# CODPRES              6173
# dtype: int64
#
# Columnas eliminadas: ['OTRO_SIT', 'FECHA_NACM']
# Filas restantes después de eliminar columnas: 2335490
#
# Valores nulos después de estandarizar 9 y 99:
# APGAR2            1112698
# APGAR1             860693
# T_GES_AGRU_CIE     629791
# TIPOFORMULARIO     629402
# ULTCURPAD          494333
# NIV_EDUP           458013
# ULTCURMAD          398360
# NIV_EDUM           340226
# IDCLASADMI         208910
# NUMCONSUL          190575
# EST_CIVM            63735
# IDFACTORRH          46397
# IDHEMOCLAS          46152
# CODPTORE            39833
# CODMUNRE            33885
# AREA_RES            32280
# N_EMB               10515
# N_HIJOSV             9376
# COD_DPTO             7444
# MUL_PARTO            6914
# SEG_SOCIAL           6752
# TIPO_PARTO           6751
# PROFESION            6751
# CODPRES              6173
# IDPERTET             6169
# ATEN_PAR             6169
# SIT_PARTO            6169
# AREANAC              6169
# COD_MUNIC             837
# T_GES                 403
# dtype: int64
#
# Se eliminaron 7444 filas con COD_DPTO nulo.
# Filas restantes después de eliminar COD_DPTO nulos: 2328046
#
# Número de filas duplicadas ANTES de eliminar: 5224
# Filas después de eliminar duplicados: 2322822

# %% [markdown]
# # Agregación de datos y creación de series temporales
#
# Para ambos análisis, nacional y departamental, se agregará el número de nacimientos por mes y año. Esto nos permitirá crear dos series temporales distintas, una para el total nacional y otra para el total por departamento. También se creará una columna de fecha para facilitar el análisis temporal.

# %%
# Agrupar por año y mes para obtener el total de nacimientos a nivel nacional
monthly_births_national = df_processed.groupby(['ANO', 'MES']).size().reset_index(name='total_births')

# Crear una columna de fecha para la serie temporal nacional
monthly_births_national['date'] = pd.to_datetime(
    monthly_births_national['ANO'].astype(str) + '-' +
    monthly_births_national['MES'].astype(str) + '-01'
)

# Ordenar por fecha
monthly_births_national = monthly_births_national.sort_values('date').reset_index(drop=True)

print("\nSerie temporal de nacimientos mensuales (Nacional - primeras filas):")
monthly_births_national.head()
# Out:
# Serie temporal de nacimientos mensuales (Nacional - primeras filas):
#     ANO  MES  total_births       date
# 0  2020    1         52871 2020-01-01
# 1  2020    2         47738 2020-02-01
# 2  2020    3         50545 2020-03-01
# 3  2020    4         48276 2020-04-01
# 4  2020    5         49781 2020-05-01

# %%
# Agrupar por departamento, año y mes para obtener el total de nacimientos
monthly_births_departmental = df_processed.groupby(['COD_DPTO', 'ANO', 'MES']).size().reset_index(name='total_births')

# Crear una columna de fecha para la serie temporal departamental
monthly_births_departmental['date'] = pd.to_datetime(
    monthly_births_departmental['ANO'].astype(str) + '-' +
    monthly_births_departmental['MES'].astype(str) + '-01'
)

# Ordenar por departamento y luego por fecha
monthly_births_departmental = monthly_births_departmental.sort_values(['COD_DPTO', 'date']).reset_index(drop=True)

print("\nSerie temporal de nacimientos mensuales por departamento (primeras filas):")
monthly_births_departmental.head()
# Out:
# Serie temporal de nacimientos mensuales por departamento (primeras filas):
#    COD_DPTO   ANO  MES  total_births       date
# 0         5  2020    1          6052 2020-01-01
# 1         5  2020    2          5431 2020-02-01
# 2         5  2020    3          5919 2020-03-01
# 3         5  2020    4          5358 2020-04-01
# 4         5  2020    5          5580 2020-05-01

# %% [markdown]
# Se añadirán características para capturar la estacionalidad (mes) y la tendencia (año) que son importantes para la predicción de series temporales. Para el modelo departamental, se incluirá el one-hot encoding del código del departamento.

# %%
# Crear características cíclicas para el mes para capturar la estacionalidad (Nacional)
monthly_births_national['month_sin'] = np.sin(2 * np.pi * monthly_births_national['MES']/12)
monthly_births_national['month_cos'] = np.cos(2 * np.pi * monthly_births_national['MES']/12)

# Usar el año como una característica numérica (Nacional)
monthly_births_national['year_numeric'] = monthly_births_national['ANO']

print("\nSerie temporal nacional con características adicionales (primeras filas):")
monthly_births_national.head()
# Out:
# Serie temporal nacional con características adicionales (primeras filas):
#     ANO  MES  total_births       date  month_sin     month_cos  year_numeric
# 0  2020    1         52871 2020-01-01   0.500000  8.660254e-01          2020
# 1  2020    2         47738 2020-02-01   0.866025  5.000000e-01          2020
# 2  2020    3         50545 2020-03-01   1.000000  6.123234e-17          2020
# 3  2020    4         48276 2020-04-01   0.866025 -5.000000e-01          2020
# 4  2020    5         49781 2020-05-01   0.500000 -8.660254e-01          2020

# %%
# Crear características cíclicas para el mes para capturar la estacionalidad (Departamental)
monthly_births_departmental['month_sin'] = np.sin(2 * np.pi * monthly_births_departmental['MES']/12)
monthly_births_departmental['month_cos'] = np.cos(2 * np.pi * monthly_births_departmental['MES']/12)

# Usar el año como una característica numérica (Departamental)
monthly_births_departmental['year_numeric'] = monthly_births_departmental['ANO']

# Convertir COD_DPTO a tipo 'category' para facilitar el one-hot encoding
monthly_births_departmental['COD_DPTO'] = monthly_births_departmental['COD_DPTO'].astype('category')

# Aplicar One-Hot Encoding a COD_DPTO
# Esto creará una nueva columna binaria para cada departamento
df_features_departmental = pd.get_dummies(monthly_births_departmental, columns=['COD_DPTO'], prefix='DPTO')

print("\nDataFrame departamental con características adicionales y One-Hot Encoding (primeras filas):")
df_features_departmental.head()
# Out:
# DataFrame departamental con características adicionales y One-Hot Encoding (primeras filas):
#     ANO  MES  total_births       date  month_sin     month_cos  year_numeric  \
# 0  2020    1          6052 2020-01-01   0.500000  8.660254e-01          2020
# 1  2020    2          5431 2020-02-01   0.866025  5.000000e-01          2020
# 2  2020    3          5919 2020-03-01   1.000000  6.123234e-17          2020
# 3  2020    4          5358 2020-04-01   0.866025 -5.000000e-01          2020
# 4  2020    5          5580 2020-05-01   0.500000 -8.660254e-01          2020
#
#    DPTO_5  DPTO_8  DPTO_11  ...  DPTO_73  DPTO_76  DPTO_81  DPTO_85  DPTO_86  \
# 0    True   False    False  ...    False    False    False    False    False
# 1    True   False    False  ...    False    False    False    False    False
# 2    True   False    False  ...    False    False    False    False    False
# 3    True   False    False  ...    False    False    False    False    False
# 4    True   False    False  ...    False    False    False    False    False
#
#    DPTO_88  DPTO_91  DPTO_94  DPTO_95  DPTO_97
# 0    False    False    False    False    False
# 1    False    False    False    False    False
# 2    False    False    False    False    False
# 3    False    False    False    False    False
# 4    False    False    False    False    False
#
# [5 rows x 39 columns]

# %% [markdown]
# # Exploración de los datos
# En esta sección, se realizará un análisis exploratorio de los datos para entender su distribución, identificar patrones, tendencias y estacionalidad en las series temporales de nacimientos, tanto a nivel nacional como departamental.

# %% [markdown]
# ## Análisis a nivel nacional

# %% [markdown]
# ### Total de nacimientos mensuales en Colombia (2020-2023)

# %%
# Visualización de la serie temporal de nacimientos
plt.figure(figsize=(14, 7))
sns.lineplot(x='date', y='total_births', data=monthly_births_national)
plt.title('Total de nacimientos mensuales en Colombia (2020-2023)')
plt.xlabel('Fecha')
plt.ylabel('Número de nacimientos')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Análisis del gráfico: Total de nacimientos mensuales en colombia (2020-2023)
#
# Este gráfico de línea muestra la evolución del número total de nacimientos mensuales en Colombia desde enero de 2020 hasta finales de 2023.
#
# Observaciones clave:
# - Tendencia decreciente: Se observa una tendencia general a la baja en el número de nacimientos a lo largo del período. Los picos de nacimientos en 2020 son notablemente más altos que los de 2023.
# - Estacionalidad pronunciada: Existe una clara estacionalidad anual. Generalmente, se aprecian picos y valles recurrentes dentro de cada año. Por ejemplo, se puede notar una disminución en los nacimientos hacia finales de cada año y un repunte a principios del siguiente.
# - Impacto de eventos externos: La caída abrupta a mediados de 2021 podría estar relacionada con el impacto de la pandemia de COVID-19 y las medidas de confinamiento implementadas en 2020 (dado que los nacimientos ocurren aproximadamente 9 meses después de la concepción).
# - Variabilidad intra-anual: Aunque hay una tendencia general a la baja, la variación mensual dentro de cada año sigue siendo significativa, lo que subraya la importancia de las características estacionales en el modelo.

# %% [markdown]
# ### Promedio de nacimientos por mes

# %%
# Análisis de estacionalidad (promedio de nacimientos por mes)
plt.figure(figsize=(10, 6))
sns.barplot(x='MES', y='total_births', data=monthly_births_national.groupby('MES', observed=False)['total_births'].mean().reset_index())
plt.title('Promedio de nacimientos por mes')
plt.xlabel('Mes')
plt.ylabel('Promedio de nacimientos')
plt.show()

# %% [markdown]
# #### Análisis del gráfico: Promedio de nacimientos por mes
#
# Este gráfico de barras ilustra el promedio de nacimientos por cada mes del año, consolidando los datos de 2020 a 2023. Permite identificar patrones estacionales recurrentes en la natalidad a nivel nacional.
#
# Observaciones clave:
# - Pico en septiembre: Se observa consistentemente que septiembre es el mes con el promedio más alto de nacimientos. Esto sugiere que las concepciones tienden a ser más frecuentes alrededor de diciembre/enero, lo que podría estar influenciado por festividades de fin de año o vacaciones.
# - Meses bajos: Febrero y abril muestran promedios ligeramente más bajos de nacimientos. Febrero, al ser el mes más corto, naturalmente tiene menos días para nacimientos, lo que podría explicar parte de esta disminución.
# - Patrón anual consistente: A pesar de las variaciones interanuales en el número total de nacimientos (como se vio en el gráfico anterior), el patrón estacional mensual se mantiene relativamente constante, lo que refuerza la importancia de las características cíclicas (month_sin, month_cos) en el modelo de predicción.
# - Implicaciones para la planificación: Este patrón estacional es crucial para la planificación de recursos en el sector salud (personal, insumos, camas de maternidad) y educación (matrículas escolares) a lo largo del año.

# %% [markdown]
# ### Distribución de la edad de la madre

# %%
# Distribución de la edad de la madre
# Excluir valores de EDAD_MADRE que mayores al rango 9
df_filtered_age = df_processed[(df_processed['EDAD_MADRE'] <= 9)]

sns.histplot(df_filtered_age['EDAD_MADRE'], bins=30, kde=True)
plt.title('Distribución de la edad de la madre (valores válidos)') # Título ajustado
plt.xlabel('Edad de la madre')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# #### Análisis del gráfico: Distribución de la edad de la madre
#
# Este histograma con una estimación de densidad de kernel (KDE) muestra la distribución de la edad de las madres en el conjunto de datos combinado (2020-2023).
#
# Observaciones clave:
# - Rango de edad principal: La mayoría de los nacimientos ocurren en madres en un rango de edad que va aproximadamente desde los 20 hasta los 34 años.
# - Pico de frecuencia: Se observa un pico de frecuencia alrededor de los 20-24 años (3), lo que indica que esta es la edad más común para la maternidad en Colombia dentro del período analizado.
# - Distribución asimétrica: La distribución es ligeramente asimétrica a la derecha, con una cola más larga hacia edades mayores, lo que sugiere que, aunque menos frecuentes, los nacimientos también ocurren en madres de mayor edad.
# - Nacimientos en adolescentes: Hay una presencia notable de nacimientos en madres adolescentes (menores de 15-19 años), lo cual es un factor demográfico importante a considerar en políticas de salud pública.

# %% [markdown]
# ### Distribución del sexo del recién nacido

# %%
# Distribución del sexo del recién nacido
plt.figure(figsize=(8, 5))
sns.countplot(x='SEXO', data=df_processed)
plt.title('Distribución del sexo del recién nacido')
plt.xlabel('Sexo (1: Masculino, 2: Femenino, 3: Indeterminado)')
plt.ylabel('Conteo')
plt.show()

# %% [markdown]
# #### Análisis del gráfico: Distribución del sexo del recién nacido
#
# Este gráfico de barras muestra la distribución del sexo de los recién nacidos en el conjunto de datos combinado (2020-2023). La variable SEXO está codificada como 1 para masculino y 2 para femenino.
#
# Observaciones clave:
# - Proporción equilibrada: Se observa una distribución casi equitativa entre nacimientos masculinos y femeninos. La barra para el sexo masculino (1) es ligeramente más alta que la del sexo femenino (2), lo cual es consistente con las tendencias biológicas globales donde nacen ligeramente más niños que niñas.
# - Ausencia de otros valores: La presencia de solo dos barras (1 y 2) indica que no hay otros valores significativos o errores en la codificación de la variable SEXO en el dataset, lo que sugiere una buena calidad de datos en esta columna.

# %% [markdown]
# ### Distribución del área de nacimiento

# %%
# Distribución del área de nacimiento (AREANAC)
plt.figure(figsize=(10, 6))
sns.countplot(x='AREANAC', data=df_processed)
plt.title('Distribución del área de nacimiento') # Título ajustado
plt.xlabel('Área de nacimiento (1: Cabecera municipal, 2: Centro poblado, 3: Rural disperso)')
plt.ylabel('Conteo')
plt.show()

# %% [markdown]
# #### Análisis del gráfico: Distribución del área de nacimiento
#
# Este gráfico de barras muestra la distribución de los nacimientos según el área geográfica donde ocurrieron, utilizando la variable AREANAC del conjunto de datos combinado (2020-2023). Los valores de AREANAC se refieren a las categorías definidas en el diccionario de datos (1: Cabecera Municipal, 2: Resto Municipal, 3: Centro Poblado, 4: Rural Disperso, 99: Sin información).
#
# Observaciones clave:
# - Predominio de cabeceras municipales: La mayor proporción de nacimientos se registra en las cabeceras municipales (Valor 1), lo cual es esperado dado que la mayoría de los hospitales y centros de salud se encuentran en estas áreas urbanas.
# - -Significancia del resto municipal: El "Resto Municipal" (Valor 2) también representa una cantidad considerable de nacimientos, lo que indica la importancia de las zonas rurales y semi-urbanas fuera de las cabeceras.
# - Menor proporción en centros poblados y rural disperso: Los "Centros Poblados" (Valor 3) y el "Rural Disperso" (Valor 4) muestran un número menor de nacimientos, lo que podría reflejar una menor densidad poblacional o un acceso más limitado a servicios de salud en estas áreas, llevando a que los nacimientos se registren en las cabeceras.
# - Valores sin información: Es importante notar la presencia de la categoría "Sin información" (Valor 99) que, aunque menor, debe ser considerada en el análisis de cobertura y calidad de los datos.

# %% [markdown]
# ## Análisis a nivel departamental

# %% [markdown]
# ### Nacimientos mensuales para los 5 departamentos con mayor número de nacimientos

# %%
# Nacimientos mensuales para los 5 departamentos con mayor número de nacimientos
top_n_departments = monthly_births_departmental.groupby('COD_DPTO', observed=False)['total_births'].sum().nlargest(5).index

plt.figure(figsize=(16, 8))
for dpto_code in top_n_departments:
    subset = monthly_births_departmental[monthly_births_departmental['COD_DPTO'] == dpto_code]
    sns.lineplot(x='date', y='total_births', data=subset, label=f'Departamento {dpto_code}', marker='o', markersize=4)
plt.title('Nacimientos mensuales para los 5 departamentos con mayor número de nacimientos')
plt.xlabel('Fecha')
plt.ylabel('Número de nacimientos')
plt.legend(title='Código de departamento')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Análisis del gráfico: Nacimientos mensuales para los 5 departamentos con mayor número de nacimientos
#
# Este gráfico de líneas muestra la evolución mensual de los nacimientos para los cinco departamentos con el mayor número total de nacimientos en Colombia durante el período 2020-2023. Cada línea representa un departamento diferente, identificado por su código.
#
# Observaciones clave:
# - Dominio de Bogotá (Departamento 11): El departamento con código 11 (Bogotá D.C.) consistentemente registra el mayor número de nacimientos mensuales, superando significativamente a los demás departamentos. Esto es esperado dada su alta densidad poblacional y concentración de servicios de salud.
# - Patrones estacionales departamentales: Aunque cada departamento tiene su propio nivel de nacimientos, se puede observar que la estacionalidad (picos y valles anuales) tiende a ser similar entre ellos, aunque con variaciones en la magnitud. Esto refuerza la idea de que factores temporales comunes influyen en la natalidad a nivel nacional.
# - Tendencias individuales: Algunos departamentos muestran tendencias ligeramente diferentes. Por ejemplo, mientras que Bogotá (11) y Antioquia (5) mantienen volúmenes altos, otros departamentos pueden mostrar una menor variabilidad o tendencias más planas.
# - Impacto de eventos: Las caídas o repuntes observados en la serie temporal nacional también se reflejan en las series departamentales, aunque con intensidades variables. Esto sugiere que los eventos a gran escala (como la pandemia) afectaron la natalidad en todo el país.

# %% [markdown]
# ### Distribución de nacimientos por departamento

# %%
# Distribución de nacimientos por departamento (general)
plt.figure(figsize=(16, 8))
sns.barplot(x='COD_DPTO', y='total_births', data=monthly_births_departmental.groupby('COD_DPTO', observed=False)['total_births'].sum().reset_index().sort_values('total_births', ascending=False))
plt.title('Total de nacimientos por Departamento (2020-2023)')
plt.xlabel('Código de departamento')
plt.ylabel('Total de nacimientos')
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Análisis del gráfico: Total de nacimientos por departamento
#
# Este gráfico de barras muestra el total acumulado de nacimientos por cada departamento de Colombia durante el período 2020-2023. Los departamentos están ordenados de mayor a menor número de nacimientos.
#
# Observaciones clave:
# - Disparidad regional: Existe una marcada disparidad en el número de nacimientos entre los departamentos. Unos pocos departamentos concentran la gran mayoría de los nacimientos, mientras que muchos otros tienen volúmenes considerablemente menores.
# - Departamentos con mayor natalidad: Los departamentos con códigos 11 (Bogotá D.C.), 5 (Antioquia), 76 (Valle del Cauca) y 8 (Atlántico) se destacan como los de mayor número de nacimientos, lo cual es coherente con su densidad poblacional y desarrollo urbano.
# - Departamentos con menor natalidad: Hacia el final del gráfico, se observan departamentos con un número muy bajo de nacimientos, lo que podría corresponder a regiones con menor población o áreas rurales dispersas.
# - Importancia para la planificación: La visualización de esta distribución es fundamental para la asignación de recursos y el diseño de políticas públicas a nivel regional, permitiendo identificar las áreas con mayor demanda de servicios relacionados con la natalidad.

# %% [markdown]
# # Selección del modelo
# Para ambos problemas de predicción (nacional y departamental), se ha elegido el algoritmo RandomForestRegressor (Regresor de Bosque Aleatorio). La justificación para esta elección se basa en las siguientes consideraciones, aplicables a ambos niveles de granularidad:
#
# - Naturaleza de los datos: Aunque los datos tienen un componente temporal, la predicción se puede abordar como un problema de regresión donde las características de entrada son el año y el mes (transformado para capturar la estacionalidad). Los Random Forests son muy efectivos en problemas de regresión con datos tabulares.
# - Capacidad para capturar relaciones no lineales: La tasa de natalidad puede estar influenciada por factores complejos y no lineales a lo largo del tiempo (ej. cambios socioeconómicos, políticas). Los Random Forests, al ser un ensamble de árboles de decisión, son capaces de modelar relaciones no lineales y capturar interacciones complejas entre las características sin necesidad de una especificación explícita.
# - Robustez a outliers y datos ruidosos: Los árboles de decisión son relativamente robustos a los valores atípicos (outliers) y al ruido en los datos, ya que las divisiones se basan en umbrales y no en la magnitud exacta de los valores. Esto es beneficioso dado que los datos demográficos pueden presentar variaciones.
# - Manejo de Características Cíclicas: Al transformar el mes en características seno y coseno, el Random Forest puede interpretar mejor la estacionalidad cíclica sin asumir una relación lineal.
# - Menor riesgo de sobreajuste (Overfitting): Aunque un solo árbol de decisión puede sobreajustarse, el Random Forest mitiga este riesgo al promediar las predicciones de múltiples árboles entrenados en diferentes subconjuntos de datos (bagging) y características (feature randomness). Esto resulta en un modelo más generalizable.
# - Facilidad de uso y buen rendimiento general: Los Random Forests son relativamente fáciles de implementar y suelen ofrecer un buen rendimiento en una amplia gama de problemas de regresión, sirviendo como una excelente línea base.

# %%
# Definir las características (X) y la variable objetivo (y) para el modelo NACIONAL
features_national = ['year_numeric', 'month_sin', 'month_cos']
target_national = 'total_births'

X_national = monthly_births_national[features_national]
y_national = monthly_births_national[target_national]

# Dividir los datos en conjuntos de entrenamiento y prueba (Nacional)
# Se utilizará una división basada en el tiempo: los años anteriores para entrenar, el último año para probar.
train_data_national = monthly_births_national[monthly_births_national['ANO'] < 2023]
test_data_national = monthly_births_national[monthly_births_national['ANO'] == 2023]

X_train_national = train_data_national[features_national]
y_train_national = train_data_national[target_national]

X_test_national = test_data_national[features_national]
y_test_national = test_data_national[target_national]

print(f"Tamaño del conjunto de entrenamiento (Nacional): {len(X_train_national)} muestras")
print(f"Tamaño del conjunto de prueba (Nacional): {len(X_test_national)} muestras")
# Out:
# Tamaño del conjunto de entrenamiento (Nacional): 36 muestras
# Tamaño del conjunto de prueba (Nacional): 12 muestras

# %%
# Definir las características (X) y la variable objetivo (y) para el modelo DEPARTAMENTAL
features_departmental = ['year_numeric', 'month_sin', 'month_cos'] + [col for col in df_features_departmental.columns if 'DPTO_' in col]
target_departmental = 'total_births'

X_departmental = df_features_departmental[features_departmental]
y_departmental = df_features_departmental[target_departmental]

# Dividir los datos en conjuntos de entrenamiento y prueba (Departamental)
# Se utilizará una división basada en el tiempo: los años anteriores para entrenar, el último año para probar.
train_data_departmental = df_features_departmental[df_features_departmental['ANO'] < 2023]
test_data_departmental = df_features_departmental[df_features_departmental['ANO'] == 2023]

X_train_departmental = train_data_departmental[features_departmental]
y_train_departmental = train_data_departmental[target_departmental]

X_test_departmental = test_data_departmental[features_departmental]
y_test_departmental = test_data_departmental[target_departmental]

print(f"Tamaño del conjunto de entrenamiento (Departamental): {len(X_train_departmental)} muestras")
print(f"Tamaño del conjunto de prueba (Departamental): {len(X_test_departmental)} muestras")

# Verificar que los departamentos en train y test son consistentes
train_departments = [col.replace('DPTO_', '') for col in X_train_departmental.columns if 'DPTO_' in col]
test_departments = [col.replace('DPTO_', '') for col in X_test_departmental.columns if 'DPTO_' in col]

if set(train_departments) != set(test_departments):
    print("\nAdvertencia: Los departamentos presentes en el conjunto de entrenamiento y prueba difieren.")
    print("Departamentos en entrenamiento:", sorted(list(set(train_departments))))
    print("Departamentos en prueba:", sorted(list(set(test_departments))))
    # Esto puede ocurrir si un departamento solo tiene datos en 2023, o solo antes de 2023.
    # El modelo de Random Forest debería manejar esto, pero es una buena observación.
# Out:
# Tamaño del conjunto de entrenamiento (Departamental): 1152 muestras
# Tamaño del conjunto de prueba (Departamental): 384 muestras

# %% [markdown]
# # Entrenamiento de los modelos
# Se procederá a entrenar dos modelos RandomForestRegressor: uno para la predicción nacional y otro para la predicción a nivel departamental. Se utilizarán los datos de 2020 a 2022 para el entrenamiento y los datos de 2023 para la evaluación de ambos modelos.

# %%
# Inicializar y entrenar el modelo RandomForestRegressor para la predicción NACIONAL
model_national = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)

print("Entrenando el modelo RandomForestRegressor (Nacional)...")
model_national.fit(X_train_national, y_train_national)
print("¡Modelo Nacional entrenado exitosamente!")
# Out:
# Entrenando el modelo RandomForestRegressor (Nacional)...
# ¡Modelo Nacional entrenado exitosamente!

# %%
# Inicializar y entrenar el modelo RandomForestRegressor para la predicción DEPARTAMENTAL
model_departmental = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)

print("\nEntrenando el modelo RandomForestRegressor (Departamental)...")
model_departmental.fit(X_train_departmental, y_train_departmental)
print("¡Modelo Departamental entrenado exitosamente!")
# Out:
# Entrenando el modelo RandomForestRegressor (Departamental)...
# ¡Modelo Departamental entrenado exitosamente!

# %% [markdown]
# # Evaluación de los modelos
# Una vez entrenados los modelos, se evaluará su rendimiento utilizando métricas comunes para problemas de regresión. Esto nos permitirá entender qué tan bien cada modelo predice los nacimientos en su respectivo conjunto de prueba (datos de 2023).
#
# Las métricas a utilizar son:
# - MAE (Mean Absolute Error - Error Absoluto Medio): Representa la magnitud promedio de los errores en un conjunto de predicciones, sin considerar su dirección. Es robusto a los valores atípicos.
# - MSE (Mean Squared Error - Error Cuadrático Medio): Mide el promedio de los cuadrados de los errores. Penaliza más los errores grandes.
# - RMSE (Root Mean Squared Error - Raíz del Error Cuadrático Medio): Es la raíz cuadrada del MSE. Tiene la misma unidad que la variable objetivo, lo que facilita su interpretación.
# - R² (Coefficient of Determination - Coeficiente de Determinación): Indica la proporción de la varianza en la variable dependiente que es predecible a partir de las variables independientes. Un valor de 1.0 indica un ajuste perfecto.

# %%
# Realizar predicciones en el conjunto de prueba (Nacional)
y_pred_national = model_national.predict(X_test_national)

# Calcular métricas de evaluación (Nacional)
mae_national = mean_absolute_error(y_test_national, y_pred_national)
mse_national = mean_squared_error(y_test_national, y_pred_national)
rmse_national = np.sqrt(mse_national)
r2_national = r2_score(y_test_national, y_pred_national)

print(f"\n--- Métricas de Evaluación del Modelo Nacional ---")
print(f"MAE (Error Absoluto Medio): {mae_national:.2f}")
print(f"MSE (Error Cuadrático Medio): {mse_national:.2f}")
print(f"RMSE (Raíz del Error Cuadrático Medio): {rmse_national:.2f}")
print(f"R² (Coeficiente de Determinación): {r2_national:.4f}")
# Out:
# --- Métricas de Evaluación del Modelo Nacional ---
# MAE (Error Absoluto Medio): 4935.12
# MSE (Error Cuadrático Medio): 26243467.32
# RMSE (Raíz del Error Cuadrático Medio): 5122.84
# R² (Coeficiente de Determinación): -7.3286

# %% [markdown]
# # Interpretación de las métricas (Nacional):
# - MAE de 4944.09 significa que, en promedio, las predicciones del modelo difieren de los valores reales en aproximadamente 4944.09 nacimientos a nivel nacional.
# - RMSE de 5131.69 indica la magnitud típica de los errores de predicción en las unidades de nacimientos a nivel nacional.
# - Un R² de -7.3574 sugiere que el -735.74% de la varianza en el número de nacimientos nacionales puede ser explicada por el modelo. Cuanto más cercano a 1, mejor es el ajuste del modelo a los datos.

# %%
# Realizar predicciones en el conjunto de prueba (Departamental)
y_pred_departmental = model_departmental.predict(X_test_departmental)

# Calcular métricas de evaluación (Departamental)
mae_departmental = mean_absolute_error(y_test_departmental, y_pred_departmental)
mse_departmental = mean_squared_error(y_test_departmental, y_pred_departmental)
rmse_departmental = np.sqrt(mse_departmental)
r2_departmental = r2_score(y_test_departmental, y_pred_departmental)

print(f"\n--- Métricas de Evaluación del Modelo Departamental ---")
print(f"MAE (Error Absoluto Medio): {mae_departmental:.2f}")
print(f"MSE (Error Cuadrático Medio): {mse_departmental:.2f}")
print(f"RMSE (Raíz del Error Cuadrático Medio): {rmse_departmental:.2f}")
print(f"R² (Coeficiente de Determinación): {r2_departmental:.4f}")
# Out:
# --- Métricas de Evaluación del Modelo Departamental ---
# MAE (Error Absoluto Medio): 158.97
# MSE (Error Cuadrático Medio): 51704.20
# RMSE (Raíz del Error Cuadrático Medio): 227.39
# R² (Coeficiente de Determinación): 0.9720

# %% [markdown]
# # Interpretación de las métricas (Departamental):
# - MAE de 158.28 significa que, en promedio, las predicciones del modelo difieren de los valores reales en aproximadamente 158.28 nacimientos a nivel departamental.
# - RMSE de 226.30 indica la magnitud típica de los errores de predicción en las unidades de nacimientos a nivel departamental.
# - Un R² de 0.9722 sugiere que el 97.22% de la varianza en el número de nacimientos departamentales puede ser explicada por el modelo. Cuanto más cercano a 1, mejor es el ajuste del modelo a los datos.

# %% [markdown]
# # Visualización de resultados
# Las visualizaciones son clave para entender el rendimiento de los modelos y la relación entre las predicciones y los valores reales. Se mostrarán gráficos comparando los nacimientos reales con los predichos para el conjunto de prueba, tanto a nivel nacional como para algunos departamentos seleccionados.

# %%
# Combinar los valores reales y predichos para la visualización (Nacional)
results_national = test_data_national.copy()
results_national['predicted_births'] = y_pred_national

plt.figure(figsize=(14, 7))
sns.lineplot(x='date', y='total_births', data=results_national, label='Nacimientos Reales', marker='o')
sns.lineplot(x='date', y='predicted_births', data=results_national, label='Nacimientos Predichos', marker='x', linestyle='--')
plt.title('Nacimientos reales vs. predichos (2023) - Nacional')
plt.xlabel('Fecha')
plt.ylabel('Número de nacimientos')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Visualización de los residuos (errores de predicción) (Nacional)
results_national['residuals'] = results_national['total_births'] - results_national['predicted_births']
plt.figure(figsize=(14, 7))
sns.lineplot(x='date', y='residuals', data=results_national, marker='o')
plt.axhline(0, color='red', linestyle='--')
plt.title('Residuos de las predicciones (Errores) - Nacional')
plt.xlabel('Fecha')
plt.ylabel('Error (real - predicho)')
plt.grid(True)
plt.show()

# %%
# Combinamos los valores reales y predichos para la visualización (Departamental)
results_departmental = test_data_departmental.copy()
results_departmental['predicted_births'] = y_pred_departmental

# Unir los resultados predichos con el DataFrame original para tener COD_DPTO
results_departmental_with_cod = monthly_births_departmental.merge(
    results_departmental[['date', 'predicted_births']],
    on='date',
    how='left'
)

top_departments_for_plot = monthly_births_departmental.groupby('COD_DPTO', observed=False)['total_births'].sum().nlargest(3).index.tolist()
# Nacimientos reales vs. predichos - Departamento
plt.figure(figsize=(18, 10))
for i, dpto_code in enumerate(top_departments_for_plot):
    plt.subplot(3, 1, i + 1) # Ajusta el layout según el número de departamentos
    subset = results_departmental_with_cod[results_departmental_with_cod['COD_DPTO'] == dpto_code]
    sns.lineplot(x='date', y='total_births', data=subset, label='Nacimientos Reales', marker='o')
    sns.lineplot(x='date', y='predicted_births', data=subset, label='Nacimientos Predichos', marker='x', linestyle='--')
    plt.title(f'Nacimientos reales vs. predichos - Departamento {dpto_code} (2023)')
    plt.xlabel('Fecha')
    plt.ylabel('Número de nacimientos')
    plt.legend()
    plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Visualización de los residuos (errores de predicción) por departamento
results_departmental_with_cod['residuals'] = results_departmental_with_cod['total_births'] - results_departmental_with_cod['predicted_births']

plt.figure(figsize=(16, 8))
sns.boxplot(x='COD_DPTO', y='residuals', data=results_departmental_with_cod)
plt.axhline(0, color='red', linestyle='--', linewidth=0.8)
plt.title('Distribución de residuos por departamento')
plt.xlabel('Código de departamento')
plt.ylabel('Error (real - predicho)')
plt.xticks(rotation=90, fontsize=8)
plt.tight_layout()
plt.show()

# %%
# Histograma de residuos para ver la distribución de errores (Departamental)
plt.figure(figsize=(10, 6))
sns.histplot(results_departmental_with_cod['residuals'], bins=50, kde=True)
plt.title('Distribución de los residuos del modelo (Departamental)')
plt.xlabel('Error de predicción (real - predicho)')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# # Conclusiones
# Los modelos RandomForestRegressor entrenados para predecir los nacimientos mensuales en Colombia, tanto a nivel nacional como departamental, han demostrado un rendimiento que busca capturar las variaciones a ambos niveles de granularidad.
#
# ## Análisis de precisión de los modelos:
# - Modelo Nacional: Las métricas (MAE, RMSE, R²) para el modelo nacional reflejan su capacidad para capturar la tendencia general y la estacionalidad de los nacimientos en el país. Un R² cercano a 1.0 indicaría una buena explicación de la varianza total.
# - Modelo Departamental: Las métricas para el modelo departamental representan el rendimiento promedio a través de todos los departamentos. Un R² alto sugiere que el modelo es capaz de capturar las variaciones temporales y las diferencias entre departamentos. Es importante recordar que el error absoluto (MAE, RMSE) debe interpretarse en el contexto de la escala de nacimientos de cada departamento.
# - Las visualizaciones son fundamentales para ambos modelos. Para el modelo nacional, nos permiten ver la alineación general de las predicciones. Para el modelo departamental, los gráficos por departamento y la distribución de residuos por departamento nos ayudan a identificar si el modelo se ajusta bien a las dinámicas específicas de cada región o si hay departamentos donde el rendimiento es subóptimo.
#
# ## Evaluación de la efectividad para predecir nacimientos en Colombia:
#
# Ambos modelos son efectivos para capturar la tendencia general y la estacionalidad de los nacimientos en sus respectivos niveles. Esto es crucial para la planificación a corto y mediano plazo. Sin embargo, es importante considerar:
#
# - Limitaciones de datos: Ambos modelos se entrenaron con solo 4 años de datos. Una serie histórica más extensa podría mejorar significativamente la capacidad de los modelos para identificar patrones a largo plazo y estacionalidades más complejas.
# - Factores externos no considerados: Los modelos actuales solo utilizan el tiempo (año y mes) y el departamento como características. Factores socioeconómicos, políticos, de salud pública (ej. pandemias, programas de planificación familiar), migraciones, y eventos específicos (ej. desastres naturales) pueden influir en la natalidad y no están incluidos. La incorporación de estas variables externas podría aumentar la precisión.
# - Heterogeneidad departamental (Modelo departamental): Aunque el enfoque global con one-hot encoding es un buen punto de partida, los departamentos pueden tener dinámicas de natalidad muy diferentes. Un modelo global podría tener dificultades para capturar todas estas particularidades si las interacciones no son lo suficientemente complejas.
# - Tamaño del conjunto de prueba: Aunque la cantidad total de microdatos es grande, la serie temporal por mes (nacional) o por mes y departamento (departamental) para un año (12 muestras por serie) sigue siendo relativamente corta. Esto puede limitar la capacidad del modelo para aprender patrones muy complejos y evaluar su generalización a futuro.
#
# ## Posibles mejoras futuras:
#
# - Ampliar series históricas: Obtener y utilizar datos de nacimientos de más años anteriores para ambos niveles de análisis.
# - Incorporar Variables Externas: Incluir características como indicadores económicos (PIB, desempleo), políticas de salud, eventos demográficos (migración), y variables específicas de cada departamento (ej. tasa de pobreza departamental, acceso a servicios de salud, etc.).
# - Modelos específicos por departamento: Si el rendimiento del modelo departamental global no es suficiente para ciertos departamentos clave, considerar entrenar modelos individuales para esas regiones con dinámicas muy particulares.
# - Modelos jerárquicos o multi-serie: Explorar técnicas más avanzadas diseñadas para pronóstico de múltiples series temporales relacionadas, como modelos jerárquicos que modelan la relación entre el total nacional y los departamentos, o modelos de series temporales multivariadas.
# - Modelos de series temporales avanzados: Explorar modelos como ARIMA, SARIMA, Prophet o redes neuronales recurrentes (RNNs) que están diseñados específicamente para datos de series temporales y pueden capturar dependencias temporales más complejas.
# - Optimización de hiperparámetros: Realizar una búsqueda de hiperparámetros (ej. GridSearchCV, RandomizedSearchCV) para los RandomForestRegressor o cualquier otro modelo elegido para encontrar la configuración óptima.

# %% [markdown]
# # Referencias
#
# - pandas development team. (s.f.). *pandas: Powerful data analysis toolkit*. Recuperado de https://pandas.pydata.org/
# - NumPy developers. (s.f.). *NumPy*. Recuperado de https://numpy.org/
# - Matplotlib. (s.f.). *Matplotlib: Python Plotting*. Recuperado de https://matplotlib.org/
# - Seaborn developers. (s.f.). *seaborn: statistical data visualization*. Recuperado de https://seaborn.pydata.org/
# - scikit-learn developers. (s.f.). *scikit-learn: machine learning in Python*. Recuperado de https://scikit-learn.org/stable/

# %% [markdown]
# ---

# %% [markdown]
# # Diccionario de Datos de Variables DANE
#
# Esta sección contiene la descripción y los valores de las variables obtenidas de los microdatos del DANE.
#
# ## Detalle por Variable
#
# ## Variable: COD_DPTO
#
# - **Etiqueta**: Departamento de Nacimiento
# - **Preguntas del Cuestionario**:
#   Departamento de Nacimiento<br><br>Código, según la División Político- Administrativa del DANE.<br><br>05= Antioquia<br>08= Atlántico<br>11= Bogotá<br>13= Bolivar<br>15= Boyaca<br>17=Caldas<br>18= Caqueta<br>19=Cauca<br>20= Cesar<br>23= Cordoba<br>25=Cundinamarca<br>27= Choco<br>41= Huila<br>44= La guajira<br>47= Magdalena<br>50= Meta<br>52= Nariño<br>54= Norte de Santander<br>63= Quindio<br>66= Risaralda<br>68= Santander<br>70= Sucre<br>73= Tolima<br>76= Valle del Cauca<br>81= Arauca<br>85= Casanare<br>86= Putumayo<br>88= Archipiélago de San Andrés, Providencia y Santa Catalina<br>91= Amazonas<br>94= Guainía<br>95= Guaviare<br>97= Vaupés<br>99= Vichada
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 05 | Antioquia | 59311 |
# | 08 | Atlántico | 32872 |
# | 11 | Bogotá | 74286 |
# | 13 | Bolivar | 28222 |
# | 15 | Boyaca | 11597 |
# | 17 | Caldas | 6666 |
# | 18 | Caqueta | 5225 |
# | 19 | Cauca | 11414 |
# | 20 | Cesar | 18975 |
# | 23 | Cordoba | 21444 |
# | 25 | Cundinamarca | 16982 |
# | 27 | Choco | 5800 |
# | 41 | Huila | 15688 |
# | 44 | La guajira | 22166 |
# | 47 | Magdalena | 19443 |
# | 50 | Meta | 13160 |
# | 52 | Nariño | 13119 |
# | 54 | Norte de Santander | 20112 |
# | 63 | Quindio | 4452 |
# | 66 | Risaralda | 8885 |
# | 68 | Santander | 22404 |
# | 70 | Sucre | 13531 |
# | 73 | Tolima | 12419 |
# | 76 | Valle del Cauca | 38397 |
# | 81 | Arauca | 3936 |
# | 85 | Casanare | 5227 |
# | 86 | Putumayo | 3798 |
# | 88 | Archipiélago de San Andrés, Providencia y Santa Catalina | 567 |
# | 91 | Amazonas | 938 |
# | 94 | Guainía | 1059 |
# | 95 | Guaviare | 1154 |
# | 97 | Vaupés | 688 |
# | 99 | Vichada | 1612 |
#
# ## Variable: COD_MUNIC
#
# - **Etiqueta**: Municipio de Nacimiento
# - **Preguntas del Cuestionario**:
#   Municipio de Nacimiento<br><br>Código, según la División Político- Administrativa del DANE.
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 001 | None | 329705 |
# | 002 | None | 48 |
# | 003 | None | 62 |
# | 004 | None | 1 |
# | 006 | None | 377 |
# | 010 | None | 82 |
# | 011 | None | 3325 |
# | 013 | None | 857 |
# | 015 | None | 17 |
# | 016 | None | 12 |
# | 019 | None | 1 |
# | 020 | None | 75 |
# | 021 | None | 4 |
# | 022 | None | 26 |
# | 025 | None | 128 |
# | 026 | None | 8 |
# | 029 | None | 7 |
# | 030 | None | 60 |
# | 031 | None | 49 |
# | 032 | None | 56 |
# | 034 | None | 79 |
# | 035 | None | 141 |
# | 036 | None | 4 |
# | 038 | None | 13 |
# | 040 | None | 78 |
# | 041 | None | 14 |
# | 042 | None | 1149 |
# | 043 | None | 24 |
# | 044 | None | 8 |
# | 045 | None | 3351 |
# | 047 | None | 11 |
# | 050 | None | 112 |
# | 051 | None | 75 |
# | 052 | None | 62 |
# | 053 | None | 51 |
# | 054 | None | 18 |
# | 055 | None | 18 |
# | 058 | None | 80 |
# | 059 | None | 3 |
# | 060 | None | 1535 |
# | 062 | None | 15 |
# | 065 | None | 137 |
# | 067 | None | 88 |
# | 068 | None | 89 |
# | 073 | None | 156 |
# | 074 | None | 48 |
# | 075 | None | 167 |
# | 077 | None | 173 |
# | 078 | None | 1016 |
# | 079 | None | 167 |
# | 081 | None | 3888 |
# | 083 | None | 2 |
# | 086 | None | 11 |
# | 087 | None | 1 |
# | 088 | None | 134 |
# | 090 | None | 257 |
# | 091 | None | 14 |
# | 092 | None | 2 |
# | 093 | None | 35 |
# | 094 | None | 46 |
# | 095 | None | 1 |
# | 097 | None | 2 |
# | 098 | None | 7 |
# | 099 | None | 148 |
# | 100 | None | 98 |
# | 101 | None | 459 |
# | 107 | None | 18 |
# | 109 | None | 2861 |
# | 110 | None | 88 |
# | 111 | None | 1719 |
# | 113 | None | 13 |
# | 120 | None | 28 |
# | 122 | None | 29 |
# | 123 | None | 1 |
# | 124 | None | 70 |
# | 125 | None | 43 |
# | 126 | None | 25 |
# | 128 | None | 17 |
# | 129 | None | 604 |
# | 130 | None | 118 |
# | 132 | None | 83 |
# | 134 | None | 8 |
# | 135 | None | 44 |
# | 136 | None | 1 |
# | 137 | None | 396 |
# | 138 | None | 31 |
# | 139 | None | 59 |
# | 140 | None | 33 |
# | 141 | None | 11 |
# | 142 | None | 73 |
# | 145 | None | 8 |
# | 147 | None | 979 |
# | 148 | None | 25 |
# | 150 | None | 178 |
# | 151 | None | 517 |
# | 152 | None | 11 |
# | 154 | None | 3514 |
# | 160 | None | 15 |
# | 161 | None | 51 |
# | 162 | None | 774 |
# | 167 | None | 14 |
# | 168 | None | 933 |
# | 169 | None | 1 |
# | 170 | None | 255 |
# | 172 | None | 1843 |
# | 174 | None | 209 |
# | 175 | None | 2376 |
# | 176 | None | 948 |
# | 178 | None | 1037 |
# | 181 | None | 1 |
# | 182 | None | 10 |
# | 183 | None | 43 |
# | 185 | None | 3 |
# | 188 | None | 2 |
# | 189 | None | 2691 |
# | 190 | None | 53 |
# | 197 | None | 14 |
# | 200 | None | 7 |
# | 203 | None | 1 |
# | 205 | None | 131 |
# | 206 | None | 48 |
# | 207 | None | 8 |
# | 209 | None | 40 |
# | 210 | None | 1 |
# | 211 | None | 5 |
# | 212 | None | 46 |
# | 215 | None | 581 |
# | 217 | None | 91 |
# | 219 | None | 153 |
# | 220 | None | 14 |
# | 221 | None | 14 |
# | 222 | None | 8 |
# | 223 | None | 91 |
# | 224 | None | 2 |
# | 225 | None | 14 |
# | 226 | None | 44 |
# | 227 | None | 22 |
# | 228 | None | 103 |
# | 229 | None | 2 |
# | 230 | None | 57 |
# | 232 | None | 1 |
# | 233 | None | 42 |
# | 234 | None | 153 |
# | 235 | None | 20 |
# | 236 | None | 19 |
# | 237 | None | 32 |
# | 238 | None | 2008 |
# | 239 | None | 6 |
# | 240 | None | 7 |
# | 243 | None | 15 |
# | 244 | None | 1161 |
# | 245 | None | 2660 |
# | 246 | None | 3 |
# | 247 | None | 48 |
# | 248 | None | 8 |
# | 250 | None | 967 |
# | 251 | None | 6 |
# | 254 | None | 1 |
# | 255 | None | 13 |
# | 256 | None | 66 |
# | 258 | None | 29 |
# | 260 | None | 8 |
# | 261 | None | 24 |
# | 263 | None | 55 |
# | 264 | None | 27 |
# | 265 | None | 913 |
# | 266 | None | 2918 |
# | 268 | None | 1564 |
# | 269 | None | 3928 |
# | 270 | None | 8 |
# | 271 | None | 12 |
# | 272 | None | 14 |
# | 275 | None | 58 |
# | 276 | None | 4534 |
# | 279 | None | 62 |
# | 281 | None | 2 |
# | 282 | None | 30 |
# | 283 | None | 68 |
# | 284 | None | 100 |
# | 286 | None | 89 |
# | 287 | None | 11 |
# | 288 | None | 1848 |
# | 290 | None | 1477 |
# | 293 | None | 1 |
# | 295 | None | 11 |
# | 296 | None | 20 |
# | 297 | None | 95 |
# | 298 | None | 2089 |
# | 299 | None | 151 |
# | 300 | None | 84 |
# | 302 | None | 5 |
# | 306 | None | 39 |
# | 307 | None | 2335 |
# | 308 | None | 8 |
# | 310 | None | 6 |
# | 313 | None | 2418 |
# | 315 | None | 10 |
# | 317 | None | 31 |
# | 318 | None | 179 |
# | 319 | None | 48 |
# | 320 | None | 151 |
# | 321 | None | 8 |
# | 322 | None | 179 |
# | 325 | None | 69 |
# | 326 | None | 8 |
# | 327 | None | 2 |
# | 330 | None | 32 |
# | 332 | None | 26 |
# | 343 | None | 163 |
# | 344 | None | 29 |
# | 347 | None | 7 |
# | 349 | None | 692 |
# | 350 | None | 51 |
# | 352 | None | 17 |
# | 353 | None | 4 |
# | 354 | None | 2 |
# | 355 | None | 190 |
# | 356 | None | 2248 |
# | 357 | None | 56 |
# | 359 | None | 41 |
# | 360 | None | 20 |
# | 361 | None | 435 |
# | 364 | None | 317 |
# | 368 | None | 14 |
# | 370 | None | 27 |
# | 372 | None | 90 |
# | 376 | None | 794 |
# | 377 | None | 25 |
# | 378 | None | 123 |
# | 380 | None | 1047 |
# | 381 | None | 3 |
# | 383 | None | 17 |
# | 385 | None | 22 |
# | 386 | None | 516 |
# | 388 | None | 8 |
# | 390 | None | 43 |
# | 392 | None | 15 |
# | 394 | None | 3 |
# | 396 | None | 1709 |
# | 397 | None | 20 |
# | 398 | None | 11 |
# | 399 | None | 593 |
# | 400 | None | 209 |
# | 401 | None | 18 |
# | 402 | None | 22 |
# | 403 | None | 3 |
# | 405 | None | 149 |
# | 406 | None | 38 |
# | 407 | None | 59 |
# | 408 | None | 132 |
# | 410 | None | 80 |
# | 411 | None | 888 |
# | 413 | None | 104 |
# | 417 | None | 2838 |
# | 418 | None | 78 |
# | 419 | None | 7 |
# | 420 | None | 5 |
# | 421 | None | 23 |
# | 425 | None | 19 |
# | 427 | None | 41 |
# | 429 | None | 34 |
# | 430 | None | 10080 |
# | 432 | None | 525 |
# | 433 | None | 82 |
# | 435 | None | 2 |
# | 436 | None | 24 |
# | 438 | None | 24 |
# | 440 | None | 133 |
# | 442 | None | 121 |
# | 443 | None | 44 |
# | 444 | None | 37 |
# | 446 | None | 3 |
# | 449 | None | 39 |
# | 450 | None | 72 |
# | 455 | None | 143 |
# | 456 | None | 315 |
# | 458 | None | 21 |
# | 460 | None | 92 |
# | 461 | None | 1 |
# | 464 | None | 25 |
# | 466 | None | 2040 |
# | 467 | None | 10 |
# | 468 | None | 1273 |
# | 469 | None | 793 |
# | 470 | None | 26 |
# | 473 | None | 452 |
# | 475 | None | 93 |
# | 476 | None | 1 |
# | 479 | None | 2 |
# | 480 | None | 164 |
# | 483 | None | 48 |
# | 486 | None | 31 |
# | 489 | None | 1 |
# | 490 | None | 491 |
# | 491 | None | 20 |
# | 494 | None | 1 |
# | 495 | None | 176 |
# | 497 | None | 10 |
# | 498 | None | 3184 |
# | 500 | None | 54 |
# | 502 | None | 6 |
# | 503 | None | 18 |
# | 504 | None | 96 |
# | 506 | None | 3 |
# | 507 | None | 4 |
# | 508 | None | 8 |
# | 511 | None | 36 |
# | 513 | None | 336 |
# | 516 | None | 4 |
# | 517 | None | 458 |
# | 518 | None | 637 |
# | 520 | None | 2257 |
# | 523 | None | 10 |
# | 524 | None | 104 |
# | 530 | None | 16 |
# | 531 | None | 3 |
# | 532 | None | 56 |
# | 533 | None | 33 |
# | 536 | None | 10 |
# | 537 | None | 1 |
# | 540 | None | 118 |
# | 541 | None | 50 |
# | 543 | None | 35 |
# | 545 | None | 12 |
# | 547 | None | 59 |
# | 548 | None | 75 |
# | 549 | None | 62 |
# | 550 | None | 36 |
# | 551 | None | 4874 |
# | 553 | None | 21 |
# | 555 | None | 2788 |
# | 558 | None | 5 |
# | 560 | None | 933 |
# | 563 | None | 41 |
# | 565 | None | 10 |
# | 568 | None | 2294 |
# | 569 | None | 20 |
# | 570 | None | 306 |
# | 571 | None | 42 |
# | 572 | None | 1033 |
# | 573 | None | 1623 |
# | 574 | None | 28 |
# | 575 | None | 35 |
# | 576 | None | 30 |
# | 577 | None | 9 |
# | 579 | None | 464 |
# | 580 | None | 143 |
# | 585 | None | 381 |
# | 586 | None | 2 |
# | 590 | None | 38 |
# | 591 | None | 27 |
# | 592 | None | 35 |
# | 594 | None | 108 |
# | 596 | None | 1 |
# | 599 | None | 27 |
# | 600 | None | 53 |
# | 604 | None | 92 |
# | 605 | None | 10 |
# | 606 | None | 65 |
# | 607 | None | 3 |
# | 610 | None | 40 |
# | 612 | None | 121 |
# | 614 | None | 554 |
# | 615 | None | 4952 |
# | 616 | None | 162 |
# | 620 | None | 9 |
# | 621 | None | 55 |
# | 622 | None | 595 |
# | 624 | None | 97 |
# | 628 | None | 36 |
# | 631 | None | 1 |
# | 632 | None | 3 |
# | 634 | None | 8 |
# | 638 | None | 2507 |
# | 642 | None | 17 |
# | 645 | None | 3 |
# | 646 | None | 21 |
# | 647 | None | 30 |
# | 649 | None | 19 |
# | 650 | None | 2942 |
# | 652 | None | 6 |
# | 653 | None | 142 |
# | 654 | None | 15 |
# | 655 | None | 85 |
# | 656 | None | 5 |
# | 657 | None | 25 |
# | 658 | None | 6 |
# | 659 | None | 94 |
# | 660 | None | 1049 |
# | 662 | None | 44 |
# | 664 | None | 57 |
# | 665 | None | 185 |
# | 666 | None | 25 |
# | 667 | None | 67 |
# | 668 | None | 13 |
# | 669 | None | 27 |
# | 670 | None | 247 |
# | 671 | None | 7 |
# | 672 | None | 12 |
# | 673 | None | 10 |
# | 674 | None | 12 |
# | 675 | None | 97 |
# | 676 | None | 14 |
# | 678 | None | 49 |
# | 679 | None | 1253 |
# | 680 | None | 33 |
# | 682 | None | 103 |
# | 683 | None | 33 |
# | 684 | None | 2 |
# | 685 | None | 9 |
# | 686 | None | 49 |
# | 687 | None | 20 |
# | 688 | None | 60 |
# | 689 | None | 58 |
# | 690 | None | 2 |
# | 692 | None | 74 |
# | 693 | None | 34 |
# | 696 | None | 33 |
# | 697 | None | 2 |
# | 698 | None | 1821 |
# | 699 | None | 5 |
# | 701 | None | 4 |
# | 702 | None | 1 |
# | 703 | None | 1 |
# | 707 | None | 78 |
# | 708 | None | 803 |
# | 710 | None | 97 |
# | 711 | None | 11 |
# | 713 | None | 43 |
# | 717 | None | 6 |
# | 718 | None | 11 |
# | 720 | None | 83 |
# | 736 | None | 2521 |
# | 740 | None | 1 |
# | 742 | None | 3 |
# | 743 | None | 143 |
# | 744 | None | 1073 |
# | 745 | None | 28 |
# | 749 | None | 1 |
# | 750 | None | 9 |
# | 753 | None | 654 |
# | 754 | None | 1721 |
# | 755 | None | 856 |
# | 756 | None | 92 |
# | 757 | None | 83 |
# | 758 | None | 3271 |
# | 759 | None | 1907 |
# | 760 | None | 14 |
# | 761 | None | 12 |
# | 763 | None | 3 |
# | 764 | None | 1 |
# | 770 | None | 109 |
# | 771 | None | 3 |
# | 772 | None | 13 |
# | 773 | None | 802 |
# | 774 | None | 1 |
# | 776 | None | 1 |
# | 777 | None | 23 |
# | 779 | None | 1 |
# | 780 | None | 46 |
# | 785 | None | 42 |
# | 786 | None | 6 |
# | 787 | None | 136 |
# | 789 | None | 26 |
# | 790 | None | 62 |
# | 791 | None | 8 |
# | 792 | None | 15 |
# | 793 | None | 2 |
# | 794 | None | 251 |
# | 797 | None | 8 |
# | 798 | None | 53 |
# | 799 | None | 29 |
# | 800 | None | 138 |
# | 801 | None | 9 |
# | 806 | None | 1 |
# | 807 | None | 369 |
# | 809 | None | 165 |
# | 810 | None | 576 |
# | 814 | None | 16 |
# | 815 | None | 83 |
# | 816 | None | 1 |
# | 817 | None | 12 |
# | 819 | None | 4 |
# | 820 | None | 97 |
# | 821 | None | 294 |
# | 822 | None | 1 |
# | 823 | None | 12 |
# | 824 | None | 90 |
# | 828 | None | 7 |
# | 832 | None | 2 |
# | 834 | None | 1887 |
# | 835 | None | 3131 |
# | 836 | None | 34 |
# | 837 | None | 1904 |
# | 838 | None | 374 |
# | 839 | None | 4 |
# | 841 | None | 1 |
# | 842 | None | 18 |
# | 843 | None | 765 |
# | 845 | None | 7 |
# | 847 | None | 5280 |
# | 849 | None | 3 |
# | 854 | None | 43 |
# | 855 | None | 70 |
# | 856 | None | 6 |
# | 858 | None | 17 |
# | 860 | None | 2 |
# | 861 | None | 545 |
# | 863 | None | 14 |
# | 865 | None | 214 |
# | 867 | None | 3 |
# | 869 | None | 5 |
# | 870 | None | 8 |
# | 871 | None | 19 |
# | 872 | None | 8 |
# | 873 | None | 88 |
# | 874 | None | 69 |
# | 875 | None | 42 |
# | 877 | None | 15 |
# | 878 | None | 17 |
# | 883 | None | 24 |
# | 884 | None | 7 |
# | 885 | None | 34 |
# | 886 | None | 6 |
# | 887 | None | 897 |
# | 888 | None | 8 |
# | 889 | None | 10 |
# | 890 | None | 1069 |
# | 892 | None | 41 |
# | 893 | None | 22 |
# | 894 | None | 5 |
# | 895 | None | 373 |
# | 897 | None | 1 |
# | 899 | None | 2174 |
# | 960 | None | 15 |
# | 980 | None | 65 |
#
# ## Variable: AREANAC
#
# - **Etiqueta**: Área del Nacimiento
# - **Preguntas del Cuestionario**:
#   Área del Nacimiento<br><br>1 = Cabecera municipal                                                                                        <br>2 = Centro poblado (Inspección, corregimiento o caserío)                                                                         <br>3 = Rural disperso                                                                    <br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Cabecera municipal | 503538 |
# | 2 | Centro poblado (Inspección, corregimiento o caserío) | 2543 |
# | 3 | Rural disperso | 5382 |
# | 9 | Sin información | 4086 |
#
# ## Variable: SIT_PARTO
#
# - **Etiqueta**: Sitio de la Parto
# - **Preguntas del Cuestionario**:
#   Sitio de la Parto<br><br>1 = Institución de salud    <br>2 = Domicilio<br>3 = Otro<br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Institución de salud | 503611 |
# | 2 | Domicilio | 6815 |
# | 3 | Otro | 1037 |
# | 9 | Sin información | 4086 |
#
# ## Variable: OTRO_SIT
#
# - **Etiqueta**: Otro sitio, ¿cuál?
# - **Preguntas del Cuestionario**:
#   Otro sitio, ¿cuál?
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | " | None | 514512 |
# | AL FRENTE DEL HOSPITAL | None | 1 |
# | ALBERGUE | None | 4 |
# | ALTA MAR EN TRASLADO DE REMISI | None | 1 |
# | AMBUANCIA | None | 1 |
# | AMBULACNIA DE BOMBEROS | None | 1 |
# | AMBULANCIA | None | 164 |
# | AMBULANCIA  POR MEDICO  DEL TR | None | 1 |
# | AMBULANCIA  VIA CHIQUINQUIRÁ | None | 1 |
# | AMBULANCIA ACUATICA | None | 2 |
# | AMBULANCIA AEREA RUTA PUERTO C | None | 1 |
# | AMBULANCIA BASICA | None | 1 |
# | AMBULANCIA BOMBEROS | None | 1 |
# | AMBULANCIA BOMBEROS CAMINO AL | None | 1 |
# | AMBULANCIA DE GAMEZA | None | 1 |
# | AMBULANCIA DE INSTITUCIÓN DURA | None | 1 |
# | AMBULANCIA DE REMISION | None | 1 |
# | AMBULANCIA DE TRANSPORTE | None | 1 |
# | AMBULANCIA DE TRASLADO | None | 6 |
# | AMBULANCIA DE TRASLADO BASICO | None | 1 |
# | AMBULANCIA DE TRASLADO VIA AGU | None | 1 |
# | AMBULANCIA EN TRASLADO | None | 1 |
# | AMBULANCIA EN VEREDA LA QUIEBR | None | 1 |
# | AMBULANCIA ESE HOSPITAL SAN JO | None | 2 |
# | AMBULANCIA INSTITUCIONAL | None | 2 |
# | AMBULANCIA INSTITUCIONAL DURAN | None | 1 |
# | AMBULANCIA INSTITUCIONAL ONZAG | None | 1 |
# | AMBULANCIA INSTITUCIONAL SALIE | None | 1 |
# | AMBULANCIA INSTITUCIONAL VÍA M | None | 1 |
# | AMBULANCIA MARITIMA  DE ESE CH | None | 1 |
# | AMBULANCIA MEDICALIZADA | None | 2 |
# | AMBULANCIA MOVIL INSTITUCIONAL | None | 1 |
# | AMBULANCIA PROVENIENTE DE MAPI | None | 1 |
# | AMBULANCIA REMISIONES DIVINO N | None | 1 |
# | AMBULANCIA SANTA CECILIA | None | 1 |
# | AMBULANCIA TRASLADO PRIMARIO | None | 1 |
# | AMBULANCIA VIA GAMARRA AGUACHI | None | 1 |
# | AMBULANCIA VIA PUERTO SANTANDE | None | 1 |
# | AMBULANCIA VÍA QUICHAYA  SILVI | None | 1 |
# | ASOCIACION DE PARTERAS ASOPARU | None | 1 |
# | ATENDIDO AMBULANCIA | None | 1 |
# | AUTOBUS | None | 1 |
# | AUTOMOVIL | None | 10 |
# | AUTOMOVIL PERSONAL FRENTE AL D | None | 1 |
# | AUTOMÓVIL | None | 1 |
# | AVION AMBULANCIA | None | 1 |
# | AVION MEDICALIZADO | None | 1 |
# | AVIONETA DE TRASLADO | None | 1 |
# | Ambulancia | None | 23 |
# | Ambulancia Medicalizada | None | 1 |
# | Ambulancia Via Marina | None | 1 |
# | Ambulancia de remisión | None | 1 |
# | Ambulancia durante traslado a | None | 1 |
# | Ambulancia institucional | None | 1 |
# | Automovil | None | 2 |
# | Automóvil | None | 1 |
# | BAHIA PORTETE | None | 1 |
# | BARBOSA | None | 1 |
# | BARRIO ALCARABAN | None | 1 |
# | BARRIO LA BOMBONERA | None | 1 |
# | BARRIO LA CANDELARIA | None | 1 |
# | BARRIO LA INVACION | None | 1 |
# | BAÑO ALBERGUE DE CUMARIBO | None | 1 |
# | BAÑO PUBLICO | None | 1 |
# | BONGO | None | 2 |
# | BONGO DURANTE EL VIAJE | None | 1 |
# | BUS | None | 1 |
# | Bongo o canoa que venia de Gua | None | 1 |
# | Bote por el rio Orinoco | None | 1 |
# | CABINA DE TAXI | None | 1 |
# | CALLE | None | 2 |
# | CALLE VEHICULO | None | 1 |
# | CALLE35A N 27 51 SAM ISIDRO | None | 1 |
# | CAMINO DE LA VEREDA FILO DE PA | None | 1 |
# | CAMINO RURAL | None | 1 |
# | CAMINO VEREDAL | None | 1 |
# | CAMPO ABIERTO | None | 7 |
# | CANOA | None | 2 |
# | CANOA LANCHA | None | 1 |
# | CARRETERA | None | 10 |
# | CARRETERA DESTAPADA | None | 1 |
# | CARRETERA EN AMBULANCIA INSTIT | None | 1 |
# | CARRETERA ENTRE VEREDA PUERTO | None | 1 |
# | CARRETERA PERTENECIENTE A CAMP | None | 1 |
# | CARRETERA VIA MAHATES  A  ARRO | None | 1 |
# | CARRETERRA  ENTRANMDO A  FLORE | None | 1 |
# | CARRO | None | 16 |
# | CARRO DE REMISION | None | 1 |
# | CARRO DE SERVICIO PUBLICO | None | 1 |
# | CARRO DE TRANSPORTE | None | 2 |
# | CARRO PARTICULA | None | 1 |
# | CARRO PARTICULAR | None | 2 |
# | CASA | None | 19 |
# | CASA DE LA PARTERA | None | 1 |
# | CASA DE PASO INDIGENA | None | 1 |
# | CASA DE VECINO | None | 1 |
# | CASA FAMILIAR DE UNAS VECINAS | None | 1 |
# | CASA VEREDA EL JUNIN | None | 1 |
# | CASERIO INDIGENA | None | 1 |
# | CENTRO  DE SALUD COLSANITAS | None | 1 |
# | CENTRO DE ATENCION | None | 1 |
# | CENTRO DE ATENCION CAÑO SUR | None | 1 |
# | CENTRO DE ATENCION DE CRISTALI | None | 1 |
# | CENTRO DE ATENCION DE VEREDA | None | 1 |
# | CENTRO DE ATENCION SAN LORENZO | None | 1 |
# | CENTRO DE SALUD | None | 2 |
# | CENTRO DE SALUD COLSANITAS  ME | None | 1 |
# | CENTRO DE SALUD COLSANITAS PUE | None | 2 |
# | CENTRO DE SALUD DE ARMA | None | 1 |
# | CENTRO DE SALUD DE CHIPAQUE | None | 1 |
# | CENTRO DE SALUD DE PUERTO BOLI | None | 2 |
# | CENTRO DE SALUD DE TALLAMBI RE | None | 1 |
# | CENTRO DE SALUD DE TASCO | None | 1 |
# | CENTRO DE SALUD DE TIUQUER RES | None | 1 |
# | CENTRO DE SALUD DE UBALA | None | 1 |
# | CENTRO DE SALUD JUAN JESUS COR | None | 1 |
# | CENTRO DE SALUD LAS FLORES | None | 1 |
# | CENTRO DE SALUD MEDIA LUNA | None | 1 |
# | CENTRO DE SALUD MORELIA | None | 1 |
# | CENTRO DE SALUD PUERETO BOLIVA | None | 1 |
# | CENTRO DE SALUD PUERTO BOLIVAR | None | 12 |
# | CEVERE | None | 1 |
# | CICLO TAXI | None | 2 |
# | CLINICA BEATRIZ | None | 1 |
# | CLINICA SAN RAFAEL | None | 1 |
# | CLINICA SANAR | None | 1 |
# | COLEGIO YEPES | None | 1 |
# | COM COCORO TOMO BEWERI | None | 1 |
# | COM SANTA FE RESG MUCO MAYORAW | None | 1 |
# | COMUNIDA | None | 1 |
# | COMUNIDAD | None | 5 |
# | COMUNIDAD  WARRANCA KM 44  VIA | None | 1 |
# | COMUNIDAD 15 DE AGOSTO RESGUAR | None | 1 |
# | COMUNIDAD ALTA MIRA RESG SARAC | None | 1 |
# | COMUNIDAD ARBOLITO RESGUARDO C | None | 2 |
# | COMUNIDAD BONGA | None | 1 |
# | COMUNIDAD CARIKACHABOQUIRA | None | 1 |
# | COMUNIDAD COAYARE | None | 1 |
# | COMUNIDAD HOLANDA RESGUARDO SA | None | 1 |
# | COMUNIDAD INDIGENA | None | 2 |
# | COMUNIDAD INDIGENA  PARREROS | None | 1 |
# | COMUNIDAD INDIGENA CHEVER | None | 1 |
# | COMUNIDAD INDIGENA EMBERA | None | 1 |
# | COMUNIDAD INDIGENA SAN JOSE DE | None | 1 |
# | COMUNIDAD INDIGENA WOUNAAN PHO | None | 1 |
# | COMUNIDAD JOVAL RESGUARDO CAÑO | None | 1 |
# | COMUNIDAD KAJANAPURUMANA | None | 1 |
# | COMUNIDAD MALICIA | None | 1 |
# | COMUNIDAD MATA PALMA RESGUARDO | None | 1 |
# | COMUNIDAD MIRABAL RESGUARDO TO | None | 1 |
# | COMUNIDAD PUERTO ILUSIÓN RESGU | None | 1 |
# | COMUNIDAD PUERTO LINDO SELVA R | None | 1 |
# | COMUNIDAD SAN ENRIQUE RESGUARD | None | 1 |
# | COMUNIDAD SANTA CRUZ RESGUARDO | None | 1 |
# | COMUNIDAD SANTA FÉ I RESGUARDO | None | 1 |
# | COMUNIDAD SANTA FÉ RESGUARDO S | None | 1 |
# | COMUNIDAD SANTA ISABEL RESGUAR | None | 1 |
# | COMUNIDAD UKUNAESITO RESGUARDO | None | 1 |
# | COMUNIDAD ULAIN KM 47  VIA RIO | None | 1 |
# | COMUNIDAD WONAIRE RESGUARDO BA | None | 1 |
# | CORREGIMIENTO FILOGRINGO | None | 1 |
# | CORREGIMIENTO SALERO EN LA AMB | None | 1 |
# | CUMARAL | None | 1 |
# | Cafeteria principal El Carmen | None | 1 |
# | Calle afuera del hospital | None | 1 |
# | Carretera Vía Pública | None | 1 |
# | Carretera entre vereda Verlin | None | 1 |
# | Carro | None | 2 |
# | Carro de paciente | None | 1 |
# | Ciner 2 | None | 1 |
# | Complejo Carcelario y Penitenc | None | 1 |
# | Comunidad Indigena | None | 1 |
# | Comunidad puerto escondido | None | 1 |
# | DE CAMINO AL PUESTO DE SALUD S | None | 1 |
# | DESCONOCIDO | None | 1 |
# | DOMICILIO | None | 22 |
# | DOMICILIO B EKONAIWA | None | 1 |
# | DOMICILIO COM SIVOCHENEO BAJO | None | 1 |
# | DOMICILIO EN VEREDA JORDAN GUI | None | 1 |
# | DOMICILIO RANCHERIA | None | 1 |
# | DUARANTE LA REMISON EN EL HOSP | None | 1 |
# | DURANTE TRANSLADO DE LA AMBULA | None | 1 |
# | EL HOGAR | None | 1 |
# | EL PATIO DE LA CASA | None | 1 |
# | EL SALADO | None | 1 |
# | EL TIGRE RIO RAPOSO | None | 1 |
# | EN   MOTOCARRO | None | 1 |
# | EN  SU HOGAR   VEREDA  EL JABO | None | 1 |
# | EN AMBULANCIA | None | 2 |
# | EN AMBULANCIA  VIA PUBLICA | None | 1 |
# | EN AMBULANCIA DE LA ESE SAN JO | None | 1 |
# | EN AMBULANCIA DE NUESTRA INSTI | None | 1 |
# | EN AMBULANCIA DURANTE REMISIÓN | None | 1 |
# | EN AMBULANCIA EN CARRETERA | None | 1 |
# | EN CAMINO HACIA EL HOSPITAL | None | 1 |
# | EN CARRO | None | 1 |
# | EN CASA DE LA HERMANA | None | 1 |
# | EN CASA DE UNOS VECINOS | None | 1 |
# | EN EL CAMINO | None | 1 |
# | EN EL CAMINO AL HOSPITAL | None | 1 |
# | EN EL CARRO | None | 2 |
# | EN EL PUERTO EN UN BONGO | None | 1 |
# | EN EL RIO CAQUETA DURANTE TRAS | None | 1 |
# | EN EL TAXI A 1 CUADRA DE LA IN | None | 1 |
# | EN EL VEHICULO QUE LA TRANSPOR | None | 1 |
# | EN LA AMBULANCIA | None | 1 |
# | EN LA CALLE | None | 2 |
# | EN LA CASA | None | 1 |
# | EN LA VIA CARRETERA | None | 1 |
# | EN LA VIA CARTAGENA DEL CHAIRA | None | 1 |
# | EN LA VIA KM18 | None | 1 |
# | EN LA VIA ORITO  PUERTO ASIS | None | 1 |
# | EN LA VIA PUBLICA EN LA ESQUIN | None | 1 |
# | EN LANCHA | None | 2 |
# | EN LANCHA ACUATICA DURANTE REM | None | 1 |
# | EN PREDIOS DEL HOSPITAL A DOND | None | 1 |
# | EN PUERTO DE JARAPETÓ | None | 1 |
# | EN SU CASA | None | 1 |
# | EN TAXI | None | 1 |
# | EN TRANSPORTE FLUVIAL DESDE DO | None | 1 |
# | EN UN BICITAXI | None | 1 |
# | EN UN CARRO | None | 1 |
# | EN UN TAXI | None | 1 |
# | EN UN VEHICULO | None | 1 |
# | EN UNA LANCHA QUE LA TRANSPORT | None | 1 |
# | EN UNA LANCHA SOBRE EL RIO QUI | None | 1 |
# | EN VEHICULO | None | 1 |
# | EN VEHÍCULO DE CAMINO HACIA LA | None | 1 |
# | EN VIA PUBLICA | None | 1 |
# | ESE CAMU  COTORRA | None | 1 |
# | ESE CXAYUCE JXUT | None | 1 |
# | ESE DE PRIMER NIVEL CAPRICHO | None | 1 |
# | ESE HOSPITAL SAN JUAN DEL SURO | None | 1 |
# | ESE HOSPITAL SAN PEDRO CLAVER | None | 1 |
# | ESE SAN JACINTO BOLIVAR | None | 1 |
# | ESTACION DE POLICIA | None | 1 |
# | EXTERNO EN VEHICULO | None | 1 |
# | EXTRA HOSPITALARIO VIA PUBLICA | None | 1 |
# | EXTRAHOSPITALARIO | None | 1 |
# | EXTRAINSTITUCIONAL | None | 1 |
# | EXTRAINSTITUCIONAL  NO ESPECIF | None | 1 |
# | Empresa trasporte | None | 1 |
# | En carro servicio publico | None | 1 |
# | En la ambulancia placa oxv405 | None | 1 |
# | En la vía de encharcazón dentr | None | 1 |
# | Espacio publico | None | 1 |
# | FINCA BELLAVISTA  VEREDA SANTA | None | 1 |
# | FINCA INDUPALMA | None | 1 |
# | FRENTE A HOTEL LAS CABAÑAS MAN | None | 1 |
# | FUNDACION REINICIO CHINAUTA | None | 1 |
# | HOGAR | None | 2 |
# | HOSPITAL DE PUERTO TEJADA | None | 1 |
# | HOSPITAL ESE CXAYUCE JXUT | None | 2 |
# | HOTEL | None | 1 |
# | Hogar | None | 1 |
# | Hospital San Vicente de paul d | None | 1 |
# | Hotel | None | 1 |
# | ICHO | None | 1 |
# | INTEMPERIE | None | 1 |
# | IPS INDIGENA CAPERA SEDE ACAND | None | 1 |
# | JONJONCITO | None | 1 |
# | KILOMETRO 23 VEREDA LA ESPERAN | None | 1 |
# | KM23 COMUNIDAD INDIGENA IPU EU | None | 1 |
# | LA LOBATA CHALUPA | None | 1 |
# | LA ORILLA DEL RIO | None | 1 |
# | LA VICTORIA MUNICIPIO PAEZ VEN | None | 1 |
# | LANCHA | None | 5 |
# | LOCAL DE IMAGENES DIAGNISTICAS | None | 1 |
# | La mallera | None | 1 |
# | MEDIO DE TRANSPORTE FLUVIAL TI | None | 1 |
# | MOTOCARRO | None | 1 |
# | Medio de transporte bote | None | 1 |
# | Montecristo | None | 1 |
# | NACIMIENTO EN AMBULANCIA INSTI | None | 1 |
# | NACIMIENTO EN TRASLADO FLUVIAL | None | 1 |
# | Nació en un taxi | None | 1 |
# | PARAMO SONSON | None | 1 |
# | PARQUE LA FLORIDA | None | 1 |
# | PARQUEADERO INSTITUCIÓN DE SAL | None | 1 |
# | PARTO DURANTE TRASLADO FLUVIAL | None | 1 |
# | PARTO EN AMBULANCIA | None | 3 |
# | PARTO EN CANOA | None | 1 |
# | PARTO EN CARRETERA VIA POPAYAN | None | 1 |
# | PARTO EN LANCHA | None | 1 |
# | PARTO EN TAXI | None | 1 |
# | PATRULLA DE POLICÍA | None | 1 |
# | PEAJE | None | 1 |
# | PENITENCIARIA | None | 1 |
# | PLAYA | None | 1 |
# | PORTAL DEL SUR | None | 1 |
# | POTRERO | None | 2 |
# | PUEBLO HITNU | None | 1 |
# | PUERTO REUDAL | None | 1 |
# | PUESTO DE SALUD BARRO BLANCO | None | 2 |
# | PUESTO DE SALUD DE ARKAKAY | None | 1 |
# | PUESTO DE SALUD DE MAYASQUER | None | 1 |
# | PUESTO DE SALUD EL VALLE | None | 5 |
# | PUESTO DE SALUD RIO MISTRATO | None | 1 |
# | PUESTO DE SALUD SAN JUAN DE LO | None | 1 |
# | PUESTO DE SALUD URAMA | None | 1 |
# | Parque Calamar | None | 1 |
# | Parqueaderos IPS Urgencias SUR | None | 1 |
# | Parto en ambulancia | None | 1 |
# | Potrero | None | 1 |
# | Puerto del rio | None | 1 |
# | Puerto fluvial | None | 1 |
# | Puesto de salud | None | 1 |
# | RANCHERIA | None | 2 |
# | RANCHERIA AMUYUWOU | None | 1 |
# | RANCHERIA ANASATTAPALA | None | 1 |
# | RANCHERIA ANAYOUMANA | None | 1 |
# | RANCHERIA ATACHI | None | 1 |
# | RANCHERIA ATSHIRARRU | None | 1 |
# | RANCHERIA CAYUSHUWAN | None | 1 |
# | RANCHERIA CHICHIPOTE | None | 1 |
# | RANCHERIA FLOR DEL PARAISO | None | 1 |
# | RANCHERIA JASHIRAIN | None | 1 |
# | RANCHERIA JIJON | None | 1 |
# | RANCHERIA JOTOMANA | None | 1 |
# | RANCHERIA JULAPA | None | 1 |
# | RANCHERIA KARRIZAL | None | 1 |
# | RANCHERIA KASISA | None | 1 |
# | RANCHERIA KAYUSHIWARARU | None | 1 |
# | RANCHERIA KEURRARIMANA | None | 1 |
# | RANCHERIA KUISA | None | 1 |
# | RANCHERIA LA VIA | None | 1 |
# | RANCHERIA MASHULAMANA | None | 1 |
# | RANCHERIA MULAMANA | None | 1 |
# | RANCHERIA MULAMANA CARDON | None | 1 |
# | RANCHERIA PORTETE | None | 1 |
# | RANCHERIA PUAY | None | 1 |
# | RANCHERIA PUSHASHI | None | 1 |
# | RANCHERIA SAPSAPA | None | 1 |
# | RANCHERIA SARRUT | None | 1 |
# | RANCHERIA TRIACHON | None | 1 |
# | RANCHERIA ULAIN | None | 1 |
# | RANCHERIA WINKUA | None | 1 |
# | RANCHERIA YOLUMANI | None | 1 |
# | RESGUARDO BARRANCOCEIBA | None | 1 |
# | RESGUARDO INDIGENA | None | 1 |
# | RESGUARDO INDIGENA KANALITOJO | None | 1 |
# | RESGUARDO LUNA ROJA | None | 1 |
# | RESGUARO INDIGENA | None | 1 |
# | RESIDENCIA COM WERETO BAJO RIO | None | 1 |
# | RESIDENCIA DE LA MADRE | None | 1 |
# | RIO MAGDALENA | None | 1 |
# | RIO PUTUMAYO EN EL TRASLADO DE | None | 1 |
# | RIO SUCIO EN UN BOTE | None | 1 |
# | RURAL DISPERSO | None | 1 |
# | Remolino | None | 1 |
# | Resguardo Indígena Hermeregild | None | 1 |
# | SAN JOSE ROBLES | None | 1 |
# | SEGUN PACIENTE EN CENTRO DE SA | None | 1 |
# | SERVICIO  PUBLICO  TAXI | None | 1 |
# | SERVICIO DE AMBULANCIA | None | 1 |
# | SERVICIO DE URGENCIAS DE LA ES | None | 1 |
# | SERVICIO PUBLICO | None | 1 |
# | SIERRA ANGOSTURA | None | 1 |
# | SIERRA NEVADA | None | 2 |
# | SITIO DE TRABAJO | None | 1 |
# | Se desconoce | None | 1 |
# | TAPARRAJI | None | 1 |
# | TAXI | None | 35 |
# | TAXI MIENTRAS SE TRASLADABA AL | None | 1 |
# | TAXI VIA PUBLICA | None | 1 |
# | TERMINAL DE TRANSPORTE DE DUIT | None | 1 |
# | TRABAJO | None | 1 |
# | TRANSPORTE ACUATICO | None | 1 |
# | TRANSPORTE FLUVIAL  RIO MAGDAL | None | 1 |
# | TRANSPORTE PUBLICO | None | 2 |
# | TRANSPORTE PUBLICO MIENTRAS SE | None | 1 |
# | TRANSPORTE PÚBLICO | None | 1 |
# | TRASLADO EMBULACIA  DE   P SAL | None | 1 |
# | TRASNSPORTE PUBLICO | None | 1 |
# | Taxi | None | 6 |
# | Taxi fuera del Hospital | None | 1 |
# | Transporte publico | None | 2 |
# | Trayecto via el carmen  barran | None | 1 |
# | VDA QUEBRA SECA | None | 1 |
# | VEHICULO | None | 21 |
# | VEHICULO AUTOMOTOR | None | 2 |
# | VEHICULO DE SERVICIO PUBLICO | None | 2 |
# | VEHICULO DE TRANSPORTE PUBLICO | None | 1 |
# | VEHICULO DE TRANSPOTE PUBLICO | None | 1 |
# | VEHICULO EN MOVIMIENTO EN VIA | None | 1 |
# | VEHICULO MAZDA  323 | None | 1 |
# | VEHICULO PARTICULAR | None | 9 |
# | VEHICULO PARTICULAR OYETO | None | 1 |
# | VEHICULO TAXI | None | 1 |
# | VEHICULO TIPO TAXI | None | 1 |
# | VEHICULO TRANSPÓRTE  CARRO | None | 1 |
# | VEHÍCULO DE TRANSPORTE | None | 2 |
# | VEREDA  LAS COLONIAS | None | 1 |
# | VEREDA LA TRINIDAD | None | 1 |
# | VEREDA LOS MANDARINOS | None | 1 |
# | VEREDA MORALITO DEL MUNICIPIO | None | 1 |
# | VEREDA PEÑONCITO | None | 1 |
# | VEREDA PORVENIR | None | 1 |
# | VEREDA TACARE MUNICIPIO DE NUN | None | 1 |
# | VERERD LA SALSITA | None | 1 |
# | VIA  PUBLICA | None | 1 |
# | VIA ENTRE VEREDA SAN FERNANDO | None | 1 |
# | VIA FLUVIAL | None | 1 |
# | VIA IRÓ ISTMINA | None | 1 |
# | VIA MONTARRON  PEQUE ANTIOQUIA | None | 1 |
# | VIA PRINICIPAL VEREDA RAMPACHA | None | 1 |
# | VIA PUBLICA | None | 19 |
# | VIA PUBLICA   VEHICULO | None | 1 |
# | VIA PUBLICA CERRO DE LA MACARE | None | 1 |
# | VIA PUBLICA EN AUTOMOVIL | None | 1 |
# | VIA PUBLICO VEHICULO | None | 1 |
# | VIA PUEBLO NUEVO A NECOCLI | None | 1 |
# | VIA SOBERANIA  VEREDA CUBUGON | None | 1 |
# | VIA VEREDAL CHOCLINA  ANZA | None | 1 |
# | VIA ZABALETAS CERRITO | None | 1 |
# | VIRREY SOLIS DE SAN DIEGO | None | 1 |
# | VOLADORA | None | 1 |
# | Vehiculo Particular | None | 1 |
# | Vehículo | None | 1 |
# | Vehículo Fluvial | None | 1 |
# | Vehículo carro | None | 1 |
# | Vereda Betoyes | None | 1 |
# | Via Castilla Coyaima Km 11 | None | 1 |
# | Via publica huisito | None | 1 |
# | Via publica rural entre sabana | None | 1 |
# | VÍA CUATRO VÍAS A  MAICAO | None | 1 |
# | VÍA CUROS  PIEDECUESTA | None | 1 |
# | VÍA PÚBLICA EN AUTOMÓVIL | None | 1 |
# | Vía Vereda Santa Marta Inspecc | None | 1 |
# | Vía publica en ambulancia carr | None | 1 |
# | Vía pública | None | 1 |
# | ZONA RURAL DISPERSA | None | 1 |
# | ambulancia | None | 38 |
# | ambulancia acuatica hospital s | None | 1 |
# | ambulancia basica | None | 1 |
# | ambulancia de traslado | None | 1 |
# | ambulancia del hospital | None | 1 |
# | ambulancia en municipio de gua | None | 1 |
# | ambulancia institucional | None | 1 |
# | ambulancia medicalizada de la | None | 1 |
# | ambulancia traslado a tercer n | None | 1 |
# | ambulancia vía Apia la Virgini | None | 1 |
# | automovil | None | 4 |
# | automóvil | None | 1 |
# | automóvil de servicio público | None | 1 |
# | bote | None | 1 |
# | cabildo indigena | None | 1 |
# | cachicamo | None | 1 |
# | calle | None | 4 |
# | calle via publica | None | 1 |
# | calle y carretera | None | 1 |
# | carretera | None | 4 |
# | carretera de Villa Cñareth | None | 1 |
# | carretera km 9  via maicao | None | 1 |
# | carro | None | 4 |
# | carro de bomberos | None | 1 |
# | carro particular | None | 3 |
# | casa | None | 11 |
# | casa de la madre | None | 1 |
# | cawasi curicagua | None | 1 |
# | centro comercial multiplaza | None | 1 |
# | centro de salud aremasain | None | 1 |
# | centro de salud de aremashain | None | 1 |
# | centro de salud de dipurdu | None | 1 |
# | centro de salud la Tagua | None | 1 |
# | centro de salud puerto Bolivar | None | 1 |
# | chalupa | None | 1 |
# | comunidad | None | 5 |
# | comunidad  PALENSO | None | 1 |
# | comunidad del 20 | None | 1 |
# | comunidad indigena | None | 1 |
# | comunidad indigena aguacate | None | 1 |
# | comunidad monte verde resguard | None | 1 |
# | comunidad pto limon resguardo | None | 1 |
# | comunidad tule | None | 1 |
# | comunidad walulapale | None | 1 |
# | dentro de un  automovil dutant | None | 1 |
# | domicilio | None | 5 |
# | domicilio com holanda resg san | None | 1 |
# | domicilio los frailes san pedr | None | 1 |
# | durante traslado en vehiculo p | None | 1 |
# | e la via que cominica piedras | None | 1 |
# | el mercado | None | 1 |
# | el vehiculo | None | 1 |
# | en ambulancia | None | 3 |
# | en ambulancia durante el trasl | None | 1 |
# | en canoa durante recorrido en | None | 1 |
# | en comunidad genareros | None | 1 |
# | en el hogar en finca veredal | None | 1 |
# | en la ambulancia | None | 1 |
# | en la calle | None | 1 |
# | en la via en ambulancia | None | 1 |
# | en locación de puesto de salud | None | 1 |
# | en su casa | None | 1 |
# | expulsivo en puesto de salud | None | 1 |
# | extrainstitucional | None | 1 |
# | finca | None | 1 |
# | finca   el diamante   resguard | None | 1 |
# | finca santa fe | None | 1 |
# | hospital local de montelibano | None | 1 |
# | hotel sofitel Baru calablanca | None | 1 |
# | jijulia | None | 1 |
# | km 1 via florenci paujil | None | 1 |
# | la calle | None | 1 |
# | lancha | None | 2 |
# | lancha acuatica | None | 1 |
# | maloka fugafana | None | 1 |
# | potrero | None | 1 |
# | puerto chalupoas | None | 1 |
# | puesto de salud | None | 3 |
# | puesto de salud de mandi | None | 1 |
# | puesto salud crstalinas | None | 1 |
# | rancheria | None | 1 |
# | rio guaviare | None | 1 |
# | rio orteguaza | None | 1 |
# | taxi | None | 8 |
# | taxi donde se  movilizaban | None | 1 |
# | transporte  fluvial | None | 1 |
# | vehiculo | None | 1 |
# | vehiculo de transporte | None | 1 |
# | vehiculo de transporte publico | None | 1 |
# | vehiculo de trasporte  publico | None | 1 |
# | vehiculo trasnporte publico | None | 1 |
# | vereda dokabu | None | 1 |
# | vereda el carmen de nazareth | None | 1 |
# | vereda el tigre de yondo | None | 1 |
# | vereda la palma | None | 1 |
# | vereda los trojes | None | 1 |
# | vereda milan | None | 1 |
# | vereda san francisco | None | 1 |
# | vereda tocaria del municipio d | None | 1 |
# | via en la vereda | None | 1 |
# | via mendez carro de transporte | None | 1 |
# | via publica | None | 5 |
# | via publica carro frente al ho | None | 1 |
# | via publica sin informacion ex | None | 1 |
# | via que comunica a Urrao con S | None | 1 |
# | viajando por el rio atabapo | None | 1 |
# | vivienda | None | 1 |
# | zona rural | None | 1 |
#
# ## Variable: SEXO
#
# - **Etiqueta**: Sexo del nacido vivo
# - **Preguntas del Cuestionario**:
#   Sexo del nacido vivo<br><br>1 = Masculino<br>2 = Femenino <br>3= Indeterminado
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Masculino | 264580 |
# | 2 | Femenino | 250932 |
# | 3 | Indeterminado | 37 |
#
# ## Variable: PESO_NAC
#
# - **Etiqueta**: Peso del nacido vivo, al nacer
# - **Preguntas del Cuestionario**:
#   Peso del nacido vivo, al nacer <br><br>1 =  Menos de 1.000<br>2 = 1.000 - 1.499<br>3 = 1.500 - 1.999 <br>4 = 2.000 - 2499<br>5 = 2.500 - 2.999<br>6 = 3.000 - 3499<br>7 = 3.500 - 3.999<br>8 = 4.000 y más<br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Menos de 1.000 | 2154 |
# | 2 | 1.000 - 1.499 | 4133 |
# | 3 | 1.500 - 1.999 | 9847 |
# | 4 | 2.000 - 2499 | 39896 |
# | 5 | 2.500 - 2.999 | 154058 |
# | 6 | 3.000 - 3499 | 212958 |
# | 7 | 3.500 - 3.999 | 76427 |
# | 8 | 4.000 y más | 9508 |
# | 9 | Sin información | 6568 |
#
# ## Variable: TALLA_NAC
#
# - **Etiqueta**: Talla del nacido vivo, al nacer
# - **Preguntas del Cuestionario**:
#   Talla del nacido vivo, al nacer <br><br> 1 = Menos de 20<br> 2 = 20-29<br> 3 = 30-39<br> 4 = 40-49<br> 5 = 50-59<br> 6 = 60 y Más.<br> 9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Menos de 20 | 4 |
# | 2 | 20-29 | 307 |
# | 3 | 30-39 | 5075 |
# | 4 | 40-49 | 236277 |
# | 5 | 50-59 | 267249 |
# | 6 | 60 y Más. | 20 |
# | 9 | Sin información | 6617 |
#
# ## Variable: ANO
#
# - **Etiqueta**: Año de la ocurrencia
# - **Preguntas del Cuestionario**:
#   Año de la ocurrencia<br><br>2023
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 2023 | None | 515549 |
#
# ## Variable: MES
#
# - **Etiqueta**: Mes de la ocurrencia
# - **Preguntas del Cuestionario**:
#   Mes de la ocurrencia<br><br>01 = Enero<br>02 = Febrero<br>03 = Marzo<br>04 = Abril<br>05 = Mayo<br>06 = Junio<br>07 = Julio<br>08 = Agosto<br>09 = Septiembre<br>10 = Octubre<br>11 = Noviembre<br>12 = Diciembre
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 01 | Enero | 45020 |
# | 02 | Febrero | 39813 |
# | 03 | Marzo | 45529 |
# | 04 | Abril | 42198 |
# | 05 | Mayo | 44045 |
# | 06 | Junio | 42745 |
# | 07 | Julio | 43241 |
# | 08 | Agosto | 44220 |
# | 09 | Septiembre | 45046 |
# | 10 | Octubre | 42396 |
# | 11 | Noviembre | 40782 |
# | 12 | Diciembre | 40514 |
#
# ## Variable: ATEN_PAR
#
# - **Etiqueta**: El parto fue atendido por
# - **Preguntas del Cuestionario**:
#   El parto fue atendido por<br><br>1 = Médico  <br>2 = Enfermero(a) <br>3 = Auxiliar de enfermería<br>4 = Promotor(a) de salud  <br>5 = Partera <br>6 = Otro persona <br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Médico | 503663 |
# | 2 | Enfermero(a) | 372 |
# | 3 | Auxiliar de enfermería | 328 |
# | 4 | Promotor(a) de salud | 78 |
# | 5 | Partera | 4243 |
# | 6 | Otro persona | 2779 |
# | 9 | Sin información | 4086 |
#
# ## Variable: T_GES
#
# - **Etiqueta**: Tiempo de gestación del nacido vivo
# - **Preguntas del Cuestionario**:
#   Tiempo de gestación del nacido vivo<br><br> 1 = Menos de 22<br> 2 = De 22 a 27<br> 3 = De 28 a 37<br> 4 = De 38 a 41<br> 5 = De 42 y más <br> 6 = Ignorado<br> 9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Menos de 22 | 19 |
# | 2 | De 22 a 27 | 1959 |
# | 3 | De 28 a 37 | 134646 |
# | 4 | De 38 a 41 | 372000 |
# | 5 | De 42 y más | 483 |
# | 6 | Ignorado | 6337 |
# | 9 | Sin información | 105 |
#
# ## Variable: T_GES_AGRU_CIE
#
# - **Etiqueta**: Tiempo de gestación del nacido vivo ajustado a la agrupación sugerida por la CIE
# - **Preguntas del Cuestionario**:
#   Tiempo de gestación del nacido vivo ajustado a la agrupación sugerida por la CIE<br><br> 1 = Menos de 22<br> 2 = De 22 a 27<br> 3 = De 28 a 36<br> 4 = De 37 a 41<br> 5 = De 42 y más <br> 6 = Ignorado<br> 9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Menos de 22 | 19 |
# | 2 | De 22 a 27 | 1959 |
# | 3 | De 28 a 36 | 54674 |
# | 4 | De 37 a 41 | 451972 |
# | 5 | De 42 y más | 483 |
# | 6 | Ignorado | 6337 |
# | 9 | Sin información | 105 |
#
# ## Variable: NUMCONSUL
#
# - **Etiqueta**: Número de consultas prenatales que tuvo la madre del nacido vivo
# - **Preguntas del Cuestionario**:
#   Número de consultas prenatales que tuvo la madre del nacido vivo<br><br>00= Ninguna<br>99 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 00 | Ninguna | 17062 |
# | 01 | None | 10874 |
# | 02 | None | 16616 |
# | 03 | None | 25135 |
# | 04 | None | 38972 |
# | 05 | None | 65605 |
# | 06 | None | 76016 |
# | 07 | None | 85645 |
# | 08 | None | 88169 |
# | 09 | None | 43835 |
# | 10 | None | 26073 |
# | 11 | None | 4945 |
# | 12 | None | 6132 |
# | 13 | None | 1532 |
# | 14 | None | 1189 |
# | 15 | None | 1816 |
# | 16 | None | 468 |
# | 17 | None | 171 |
# | 18 | None | 229 |
# | 19 | None | 44 |
# | 20 | None | 428 |
# | 21 | None | 19 |
# | 22 | None | 23 |
# | 23 | None | 19 |
# | 24 | None | 14 |
# | 25 | None | 33 |
# | 99 | Sin información | 4485 |
#
# ## Variable: TIPO_PARTO
#
# - **Etiqueta**: Tipo de parto de este nacimiento
# - **Preguntas del Cuestionario**:
#   Tipo de parto de este nacimiento<br><br>1 = Espontáneo             <br>2 = Cesárea<br>3 = Instrumentado<br>4 = Ignorado <br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Espontáneo | 249961 |
# | 2 | Cesárea | 255471 |
# | 3 | Instrumentado | 5632 |
# | 4 | Ignorado | 0 |
# | 9 | Sin información | 4485 |
#
# ## Variable: MUL_PARTO
#
# - **Etiqueta**: Multiplicidad del embarazo
# - **Preguntas del Cuestionario**:
#   Multiplicidad del embarazo<br><br>1 = Simple           <br>2 = Doble<br>3 = Triple<br>4 = Cuádruple o más <br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Simple | 501874 |
# | 2 | Doble | 9101 |
# | 3 | Triple | 102 |
# | 4 | Cuádruple o más | 5 |
# | 9 | Sin información | 4467 |
#
# ## Variable: APGAR1
#
# - **Etiqueta**: APGAR al minuto del nacido vivo
# - **Preguntas del Cuestionario**:
#   APGAR al minuto del nacido vivo<br><br>01 - 10 = Al minuto<br>99 = sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 01 | Al minuto | 481 |
# | 02 | Al minuto | 301 |
# | 03 | Al minuto | 608 |
# | 04 | Al minuto | 896 |
# | 05 | Al minuto | 2322 |
# | 06 | Al minuto | 3614 |
# | 07 | Al minuto | 15204 |
# | 08 | Al minuto | 104424 |
# | 09 | Al minuto | 222957 |
# | 10 | Al minuto | 152804 |
# | 99 | Sin información | 11938 |
#
# ## Variable: APGAR2
#
# - **Etiqueta**: APGAR a los cinco minutos del nacido vivo
# - **Preguntas del Cuestionario**:
#   APGAR a los cinco minutos del nacido vivo<br><br>01 - 10 = A los cinco minutos<br>99 = sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 01 | A los cinco minutos | 428 |
# | 02 | A los cinco minutos | 158 |
# | 03 | A los cinco minutos | 278 |
# | 04 | A los cinco minutos | 457 |
# | 05 | A los cinco minutos | 1266 |
# | 06 | A los cinco minutos | 1936 |
# | 07 | A los cinco minutos | 6040 |
# | 08 | A los cinco minutos | 29257 |
# | 09 | A los cinco minutos | 249720 |
# | 10 | A los cinco minutos | 214071 |
# | 99 | Sin información | 11938 |
#
# ## Variable: IDHEMOCLAS
#
# - **Etiqueta**: Hemoclasificación del nacido vivo: Grupo Sanguíneo
# - **Preguntas del Cuestionario**:
#   Hemoclasificación del nacido vivo: Grupo Sanguíneo<br><br>1 = A    <br>2 = B<br>3 = O<br>4 = AB                                                                                                                 <br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | A | 128160 |
# | 2 | B | 47303 |
# | 3 | O | 326605 |
# | 4 | AB | 8884 |
# | 9 | Sin información | 4597 |
#
# ## Variable: IDFACTORRH
#
# - **Etiqueta**: Hemoclasificación del nacido vivo:   Factor RH
# - **Preguntas del Cuestionario**:
#   Hemoclasificación del nacido vivo:  Factor RH<br><br>1 = Positivo  <br>2 = Negativo<br>9= Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Positivo | 487198 |
# | 2 | Negativo | 23748 |
# | 9 | Sin información | 4603 |
#
# ## Variable: IDPERTET
#
# - **Etiqueta**: De acuerdo con la cultura, pueblo o rasgos físicos, el nacido vivo es reconocido por sus padres como
# - **Preguntas del Cuestionario**:
#   De acuerdo con la cultura, pueblo o rasgos físicos, el nacido vivo es reconocido por sus padres como<br><br>1 = Indígena                                                  <br>2 = Rom (Gitano)                                                                     <br>3 = Raizal del archipiélago de San Andrés y Providencia                                                                  <br>4 = Palenquero de San Basilio         <br>5 = Negro(a), mulato(a), afrocolombiano(a) o afrodescendiente                                                                   <br>6 = Ninguna de las anteriores  <br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Indígena | 27068 |
# | 2 | Rom (Gitano) | 26 |
# | 3 | Raizal del archipiélago de San Andrés y Providencia | 306 |
# | 4 | Palenquero de San Basilio | 34 |
# | 5 | Negro(a), mulato(a), afrocolombiano(a) o afrodescendiente | 19382 |
# | 6 | Ninguna de las anteriores | 464647 |
# | 9 | Sin información | 4086 |
#
# ## Variable: EDAD_MADRE
#
# - **Etiqueta**: Edad de la madre a la fecha del parto
# - **Preguntas del Cuestionario**:
#   Edad de la madre a la fecha del parto<br><br>1 = De 10-14 Años<br>2 = De 15-19 Años<br>3 = De 20-24 Años<br>4 = De 25-29 Años<br>5 = De 30-34 Años<br>6 = De 35-39 Años<br>7 = De 40-44 Años<br>8 = De 45-49 Años<br>9 = De 50-54 Años<br>99 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | De 10-14 Años | 3837 |
# | 2 | De 15-19 Años | 78617 |
# | 3 | De 20-24 Años | 138341 |
# | 4 | De 25-29 Años | 132592 |
# | 5 | De 30-34 Años | 96828 |
# | 6 | De 35-39 Años | 50246 |
# | 7 | De 40-44 Años | 13723 |
# | 8 | De 45-49 Años | 955 |
# | 9 | De 50-54 Años | 47 |
# | 99 | Sin información | 363 |
#
# ## Variable: EST_CIVM
#
# - **Etiqueta**: Estado conyugal de la madre
# - **Preguntas del Cuestionario**:
#   Estado conyugal de la madre<br><br>1 = No está casada y lleva dos o más años viviendo con su pareja<br>2 = No está casada y lleva menos de dos años viviendo con su pareja                                                                                      <br>3 = Está separada, divorciada       <br>4 = Está viuda                                    <br>5 = Está soltera <br>6 = Está casada<br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | No está casada y lleva dos o más años viviendo con su pareja | 285121 |
# | 2 | No está casada y lleva menos de dos años viviendo con su pareja | 87664 |
# | 3 | Está separada, divorciada | 1200 |
# | 4 | Está viuda | 378 |
# | 5 | Está soltera | 61486 |
# | 6 | Está casada | 65258 |
# | 9 | Sin información | 14442 |
#
# ## Variable: NIV_EDUM
#
# - **Etiqueta**: Ultimo nivel de estudio que aprobó la madre
# - **Preguntas del Cuestionario**:
#   Nivel educativo del la madre       <br><br>1 = Preescolar<br>2 = Básica primaria<br>3 = Básica secundaria <br>4 = Media académica o clásica <br>5 = Media técnica <br>6 = Normalista<br>7 = Técnica profesional  <br>8 = Tecnológica<br>9 = Profesional<br>10 = Especialización<br>11 = Maestría<br>12 = Doctorado                                                                                    <br>13 = Ninguno       <br>99 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 01 | Preescolar | 649 |
# | 02 | Básica primaria | 51931 |
# | 03 | Básica secundaria | 107633 |
# | 04 | Media académica o clásica | 173292 |
# | 05 | Media técnica | 10490 |
# | 06 | Normalista | 633 |
# | 07 | Técnica profesional | 45587 |
# | 08 | Tecnológica | 28866 |
# | 09 | Profesional | 63120 |
# | 10 | Especialización | 7458 |
# | 11 | Maestría | 2464 |
# | 12 | Doctorado | 115 |
# | 13 | Ninguno | 5323 |
# | 99 | Sin información | 17988 |
#
# ## Variable: ULTCURMAD
#
# - **Etiqueta**: Ultimo año o grado aprobado de la madre
# - **Preguntas del Cuestionario**:
#   Ultimo año o grado aprobado de la madre<br><br>99 = Sin información.
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 99 | Sin información. | 17988 |
#
# ## Variable: CODPRES
#
# - **Etiqueta**: País de residencia habitual de la madre en el extranjero
# - **Preguntas del Cuestionario**:
#   País de residencia habitual de la madre en el extranjero<br><br>Código, según listado de países  ISO 3166/2
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | " | None | 4088 |
# | 068 | None | 1 |
# | 076 | None | 42 |
# | 152 | None | 2 |
# | 170 | Colombia | 508299 |
# | 214 | None | 1 |
# | 218 | None | 18 |
# | 276 | None | 2 |
# | 320 | None | 2 |
# | 324 | None | 1 |
# | 332 | None | 2 |
# | 380 | None | 1 |
# | 422 | None | 1 |
# | 430 | None | 1 |
# | 484 | None | 1 |
# | 531 | None | 1 |
# | 533 | None | 17 |
# | 591 | None | 2 |
# | 604 | None | 16 |
# | 608 | None | 1 |
# | 630 | None | 2 |
# | 660 | None | 1 |
# | 724 | None | 1 |
# | 840 | None | 2 |
# | 862 | None | 3044 |
#
# ## Variable: CODPTORE
#
# - **Etiqueta**: Departamento de residencia habitual de la madre
# - **Preguntas del Cuestionario**:
#   Departamento de residencia habitual de la madre<br><br>Código, según la División Político- Administrativa del DANE.
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | " | None | 7250 |
# | 05 | Antioquia | 59017 |
# | 08 | Atlántico | 31727 |
# | 11 | Bogotá | 60912 |
# | 13 | Bolivar | 29953 |
# | 15 | Boyaca | 11327 |
# | 17 | Caldas | 6704 |
# | 18 | Caqueta | 5137 |
# | 19 | Cauca | 14115 |
# | 20 | Cesar | 18144 |
# | 23 | Cordoba | 21080 |
# | 25 | Cundinamarca | 29061 |
# | 27 | Choco | 6642 |
# | 41 | Huila | 15148 |
# | 44 | La guajira | 20333 |
# | 47 | Magdalena | 19865 |
# | 50 | Meta | 12989 |
# | 52 | Nariño | 12610 |
# | 54 | Norte de Santander | 18974 |
# | 63 | Quindio | 4224 |
# | 66 | Risaralda | 8196 |
# | 68 | Santander | 21890 |
# | 70 | Sucre | 11986 |
# | 73 | Tolima | 13073 |
# | 76 | Valle del Cauca | 36514 |
# | 81 | Arauca | 3482 |
# | 85 | Casanare | 5429 |
# | 86 | Putumayo | 3997 |
# | 88 | Archipiélago de San Andrés, Providencia y Santa Catalina | 608 |
# | 91 | Amazonas | 903 |
# | 94 | Guainía | 738 |
# | 95 | Guaviare | 1131 |
# | 97 | Vaupés | 690 |
# | 99 | Vichada | 1700 |
#
# ## Variable: CODMUNRE
#
# - **Etiqueta**: Municipio de residencia habitual de la madre
# - **Preguntas del Cuestionario**:
#   Municipio de residencia habitual de la madre<br><br>Municipio de residencia habitual, según la División Político- Administrativa del DANE
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | " | None | 7250 |
# | 001 | None | 221589 |
# | 002 | None | 137 |
# | 003 | None | 370 |
# | 004 | None | 15 |
# | 006 | None | 2004 |
# | 010 | None | 416 |
# | 011 | None | 1593 |
# | 013 | None | 1461 |
# | 015 | None | 115 |
# | 016 | None | 204 |
# | 019 | None | 83 |
# | 020 | None | 473 |
# | 021 | None | 28 |
# | 022 | None | 167 |
# | 024 | None | 30 |
# | 025 | None | 197 |
# | 026 | None | 113 |
# | 029 | None | 47 |
# | 030 | None | 628 |
# | 031 | None | 257 |
# | 032 | None | 360 |
# | 034 | None | 330 |
# | 035 | None | 448 |
# | 036 | None | 198 |
# | 038 | None | 86 |
# | 040 | None | 292 |
# | 041 | None | 135 |
# | 042 | None | 756 |
# | 043 | None | 98 |
# | 044 | None | 65 |
# | 045 | None | 1876 |
# | 047 | None | 137 |
# | 050 | None | 480 |
# | 051 | None | 647 |
# | 052 | None | 897 |
# | 053 | None | 424 |
# | 054 | None | 46 |
# | 055 | None | 144 |
# | 058 | None | 455 |
# | 059 | None | 12 |
# | 060 | None | 791 |
# | 062 | None | 84 |
# | 065 | None | 556 |
# | 067 | None | 221 |
# | 068 | None | 701 |
# | 073 | None | 131 |
# | 074 | None | 288 |
# | 075 | None | 379 |
# | 077 | None | 394 |
# | 078 | None | 1381 |
# | 079 | None | 1015 |
# | 081 | None | 3044 |
# | 083 | None | 26 |
# | 086 | None | 44 |
# | 087 | None | 78 |
# | 088 | None | 4786 |
# | 090 | None | 653 |
# | 091 | None | 67 |
# | 092 | None | 57 |
# | 093 | None | 144 |
# | 094 | None | 120 |
# | 095 | None | 12 |
# | 097 | None | 46 |
# | 098 | None | 208 |
# | 099 | None | 271 |
# | 100 | None | 347 |
# | 101 | None | 277 |
# | 104 | None | 49 |
# | 106 | None | 17 |
# | 107 | None | 65 |
# | 109 | None | 3361 |
# | 110 | None | 677 |
# | 111 | None | 933 |
# | 113 | None | 318 |
# | 114 | None | 13 |
# | 120 | None | 416 |
# | 121 | None | 14 |
# | 122 | None | 208 |
# | 123 | None | 102 |
# | 124 | None | 429 |
# | 125 | None | 230 |
# | 126 | None | 991 |
# | 128 | None | 72 |
# | 129 | None | 610 |
# | 130 | None | 1822 |
# | 131 | None | 15 |
# | 132 | None | 402 |
# | 134 | None | 58 |
# | 135 | None | 91 |
# | 136 | None | 6 |
# | 137 | None | 881 |
# | 138 | None | 146 |
# | 139 | None | 248 |
# | 140 | None | 270 |
# | 141 | None | 205 |
# | 142 | None | 359 |
# | 145 | None | 31 |
# | 147 | None | 1688 |
# | 148 | None | 743 |
# | 150 | None | 766 |
# | 151 | None | 187 |
# | 152 | None | 91 |
# | 154 | None | 1537 |
# | 160 | None | 144 |
# | 161 | None | 128 |
# | 162 | None | 1282 |
# | 167 | None | 113 |
# | 168 | None | 766 |
# | 169 | None | 14 |
# | 170 | None | 1985 |
# | 172 | None | 1088 |
# | 174 | None | 471 |
# | 175 | None | 1869 |
# | 176 | None | 567 |
# | 178 | None | 545 |
# | 179 | None | 21 |
# | 180 | None | 15 |
# | 181 | None | 87 |
# | 182 | None | 480 |
# | 183 | None | 345 |
# | 185 | None | 64 |
# | 187 | None | 21 |
# | 188 | None | 144 |
# | 189 | None | 2422 |
# | 190 | None | 609 |
# | 197 | None | 178 |
# | 200 | None | 292 |
# | 203 | None | 42 |
# | 204 | None | 183 |
# | 205 | None | 315 |
# | 206 | None | 365 |
# | 207 | None | 78 |
# | 209 | None | 163 |
# | 210 | None | 39 |
# | 211 | None | 19 |
# | 212 | None | 964 |
# | 214 | None | 310 |
# | 215 | None | 868 |
# | 217 | None | 317 |
# | 218 | None | 20 |
# | 219 | None | 58 |
# | 220 | None | 33 |
# | 221 | None | 259 |
# | 222 | None | 205 |
# | 223 | None | 339 |
# | 224 | None | 168 |
# | 225 | None | 79 |
# | 226 | None | 351 |
# | 227 | None | 251 |
# | 228 | None | 642 |
# | 229 | None | 112 |
# | 230 | None | 184 |
# | 232 | None | 28 |
# | 233 | None | 560 |
# | 234 | None | 230 |
# | 235 | None | 407 |
# | 236 | None | 76 |
# | 237 | None | 167 |
# | 238 | None | 1704 |
# | 239 | None | 40 |
# | 240 | None | 114 |
# | 243 | None | 60 |
# | 244 | None | 1148 |
# | 245 | None | 1565 |
# | 246 | None | 46 |
# | 247 | None | 190 |
# | 248 | None | 468 |
# | 250 | None | 3496 |
# | 251 | None | 68 |
# | 254 | None | 43 |
# | 255 | None | 148 |
# | 256 | None | 658 |
# | 258 | None | 315 |
# | 260 | None | 458 |
# | 261 | None | 425 |
# | 263 | None | 168 |
# | 264 | None | 110 |
# | 265 | None | 309 |
# | 266 | None | 1246 |
# | 268 | None | 1153 |
# | 269 | None | 1612 |
# | 270 | None | 82 |
# | 271 | None | 29 |
# | 272 | None | 168 |
# | 275 | None | 683 |
# | 276 | None | 2676 |
# | 279 | None | 826 |
# | 281 | None | 92 |
# | 282 | None | 106 |
# | 283 | None | 303 |
# | 284 | None | 170 |
# | 286 | None | 857 |
# | 287 | None | 151 |
# | 288 | None | 1392 |
# | 290 | None | 1268 |
# | 293 | None | 34 |
# | 295 | None | 386 |
# | 296 | None | 809 |
# | 297 | None | 90 |
# | 298 | None | 961 |
# | 299 | None | 121 |
# | 300 | None | 918 |
# | 302 | None | 53 |
# | 306 | None | 510 |
# | 307 | None | 2905 |
# | 308 | None | 361 |
# | 310 | None | 69 |
# | 312 | None | 61 |
# | 313 | None | 1247 |
# | 315 | None | 58 |
# | 317 | None | 228 |
# | 318 | None | 1544 |
# | 319 | None | 579 |
# | 320 | None | 783 |
# | 321 | None | 84 |
# | 322 | None | 253 |
# | 323 | None | 36 |
# | 324 | None | 36 |
# | 325 | None | 228 |
# | 326 | None | 57 |
# | 327 | None | 50 |
# | 328 | None | 26 |
# | 330 | None | 107 |
# | 332 | None | 55 |
# | 335 | None | 56 |
# | 339 | None | 34 |
# | 343 | None | 92 |
# | 344 | None | 146 |
# | 347 | None | 86 |
# | 349 | None | 263 |
# | 350 | None | 308 |
# | 352 | None | 128 |
# | 353 | None | 28 |
# | 354 | None | 29 |
# | 355 | None | 380 |
# | 356 | None | 1001 |
# | 357 | None | 166 |
# | 359 | None | 390 |
# | 360 | None | 2015 |
# | 361 | None | 682 |
# | 362 | None | 19 |
# | 364 | None | 1979 |
# | 367 | None | 37 |
# | 368 | None | 155 |
# | 370 | None | 139 |
# | 372 | None | 366 |
# | 376 | None | 552 |
# | 377 | None | 457 |
# | 378 | None | 652 |
# | 380 | None | 1206 |
# | 381 | None | 60 |
# | 383 | None | 204 |
# | 385 | None | 261 |
# | 386 | None | 320 |
# | 388 | None | 36 |
# | 390 | None | 131 |
# | 392 | None | 78 |
# | 394 | None | 31 |
# | 396 | None | 1060 |
# | 397 | None | 139 |
# | 398 | None | 120 |
# | 399 | None | 239 |
# | 400 | None | 1694 |
# | 401 | None | 300 |
# | 402 | None | 120 |
# | 403 | None | 96 |
# | 405 | None | 957 |
# | 406 | None | 466 |
# | 407 | None | 327 |
# | 408 | None | 138 |
# | 410 | None | 424 |
# | 411 | None | 515 |
# | 413 | None | 161 |
# | 417 | None | 1492 |
# | 418 | None | 620 |
# | 419 | None | 184 |
# | 420 | None | 29 |
# | 421 | None | 347 |
# | 425 | None | 140 |
# | 426 | None | 39 |
# | 427 | None | 84 |
# | 429 | None | 515 |
# | 430 | None | 8852 |
# | 432 | None | 224 |
# | 433 | None | 1874 |
# | 435 | None | 53 |
# | 436 | None | 316 |
# | 438 | None | 75 |
# | 440 | None | 1475 |
# | 442 | None | 828 |
# | 443 | None | 444 |
# | 444 | None | 177 |
# | 446 | None | 22 |
# | 449 | None | 447 |
# | 450 | None | 319 |
# | 455 | None | 290 |
# | 456 | None | 368 |
# | 458 | None | 128 |
# | 460 | None | 459 |
# | 461 | None | 26 |
# | 464 | None | 331 |
# | 466 | None | 1163 |
# | 467 | None | 38 |
# | 468 | None | 720 |
# | 469 | None | 236 |
# | 470 | None | 339 |
# | 473 | None | 2408 |
# | 475 | None | 104 |
# | 476 | None | 40 |
# | 479 | None | 57 |
# | 480 | None | 441 |
# | 483 | None | 296 |
# | 486 | None | 405 |
# | 488 | None | 40 |
# | 489 | None | 13 |
# | 490 | None | 1241 |
# | 491 | None | 217 |
# | 494 | None | 33 |
# | 495 | None | 691 |
# | 497 | None | 69 |
# | 498 | None | 1715 |
# | 500 | None | 522 |
# | 501 | None | 17 |
# | 502 | None | 26 |
# | 503 | None | 210 |
# | 504 | None | 314 |
# | 506 | None | 60 |
# | 507 | None | 62 |
# | 508 | None | 248 |
# | 511 | None | 68 |
# | 513 | None | 378 |
# | 514 | None | 16 |
# | 516 | None | 323 |
# | 517 | None | 933 |
# | 518 | None | 547 |
# | 520 | None | 3057 |
# | 522 | None | 24 |
# | 523 | None | 226 |
# | 524 | None | 616 |
# | 530 | None | 229 |
# | 531 | None | 42 |
# | 532 | None | 363 |
# | 533 | None | 171 |
# | 535 | None | 93 |
# | 536 | None | 10 |
# | 537 | None | 42 |
# | 540 | None | 300 |
# | 541 | None | 414 |
# | 542 | None | 51 |
# | 543 | None | 63 |
# | 545 | None | 195 |
# | 547 | None | 1792 |
# | 548 | None | 640 |
# | 549 | None | 362 |
# | 550 | None | 330 |
# | 551 | None | 2584 |
# | 553 | None | 226 |
# | 555 | None | 2370 |
# | 558 | None | 162 |
# | 560 | None | 1621 |
# | 563 | None | 443 |
# | 564 | None | 49 |
# | 565 | None | 39 |
# | 568 | None | 2100 |
# | 569 | None | 154 |
# | 570 | None | 1001 |
# | 571 | None | 241 |
# | 572 | None | 1223 |
# | 573 | None | 1815 |
# | 574 | None | 253 |
# | 575 | None | 388 |
# | 576 | None | 56 |
# | 577 | None | 79 |
# | 579 | None | 423 |
# | 580 | None | 806 |
# | 585 | None | 557 |
# | 586 | None | 194 |
# | 590 | None | 150 |
# | 591 | None | 279 |
# | 592 | None | 255 |
# | 594 | None | 520 |
# | 596 | None | 45 |
# | 599 | None | 214 |
# | 600 | None | 282 |
# | 604 | None | 415 |
# | 605 | None | 84 |
# | 606 | None | 612 |
# | 607 | None | 171 |
# | 610 | None | 176 |
# | 612 | None | 299 |
# | 614 | None | 525 |
# | 615 | None | 2797 |
# | 616 | None | 455 |
# | 620 | None | 66 |
# | 621 | None | 480 |
# | 622 | None | 390 |
# | 624 | None | 317 |
# | 628 | None | 94 |
# | 631 | None | 769 |
# | 632 | None | 120 |
# | 634 | None | 398 |
# | 638 | None | 1426 |
# | 642 | None | 119 |
# | 645 | None | 64 |
# | 646 | None | 356 |
# | 647 | None | 178 |
# | 649 | None | 168 |
# | 650 | None | 866 |
# | 652 | None | 45 |
# | 653 | None | 141 |
# | 654 | None | 255 |
# | 655 | None | 489 |
# | 656 | None | 123 |
# | 657 | None | 378 |
# | 658 | None | 101 |
# | 659 | None | 458 |
# | 660 | None | 1717 |
# | 662 | None | 201 |
# | 664 | None | 309 |
# | 665 | None | 505 |
# | 666 | None | 28 |
# | 667 | None | 440 |
# | 668 | None | 368 |
# | 669 | None | 53 |
# | 670 | None | 1986 |
# | 671 | None | 130 |
# | 672 | None | 390 |
# | 673 | None | 237 |
# | 674 | None | 164 |
# | 675 | None | 765 |
# | 676 | None | 154 |
# | 678 | None | 899 |
# | 679 | None | 755 |
# | 680 | None | 202 |
# | 681 | None | 35 |
# | 682 | None | 743 |
# | 683 | None | 540 |
# | 684 | None | 40 |
# | 685 | None | 354 |
# | 686 | None | 853 |
# | 687 | None | 221 |
# | 688 | None | 739 |
# | 689 | None | 528 |
# | 690 | None | 117 |
# | 692 | None | 254 |
# | 693 | None | 227 |
# | 694 | None | 49 |
# | 696 | None | 116 |
# | 697 | None | 458 |
# | 698 | None | 1335 |
# | 699 | None | 51 |
# | 701 | None | 32 |
# | 702 | None | 209 |
# | 703 | None | 165 |
# | 705 | None | 7 |
# | 707 | None | 353 |
# | 708 | None | 900 |
# | 710 | None | 421 |
# | 711 | None | 203 |
# | 713 | None | 713 |
# | 717 | None | 215 |
# | 718 | None | 77 |
# | 720 | None | 559 |
# | 723 | None | 5 |
# | 736 | None | 1742 |
# | 740 | None | 369 |
# | 742 | None | 370 |
# | 743 | None | 533 |
# | 744 | None | 286 |
# | 745 | None | 516 |
# | 749 | None | 129 |
# | 750 | None | 308 |
# | 753 | None | 881 |
# | 754 | None | 6324 |
# | 755 | None | 472 |
# | 756 | None | 427 |
# | 757 | None | 291 |
# | 758 | None | 6894 |
# | 759 | None | 1221 |
# | 760 | None | 205 |
# | 761 | None | 142 |
# | 762 | None | 19 |
# | 763 | None | 72 |
# | 764 | None | 97 |
# | 769 | None | 124 |
# | 770 | None | 918 |
# | 771 | None | 206 |
# | 772 | None | 198 |
# | 773 | None | 964 |
# | 774 | None | 13 |
# | 776 | None | 68 |
# | 777 | None | 274 |
# | 778 | None | 19 |
# | 779 | None | 58 |
# | 780 | None | 479 |
# | 781 | None | 49 |
# | 785 | None | 404 |
# | 786 | None | 137 |
# | 787 | None | 392 |
# | 788 | None | 57 |
# | 789 | None | 87 |
# | 790 | None | 414 |
# | 791 | None | 238 |
# | 792 | None | 34 |
# | 793 | None | 95 |
# | 794 | None | 791 |
# | 797 | None | 158 |
# | 798 | None | 251 |
# | 799 | None | 384 |
# | 800 | None | 444 |
# | 801 | None | 108 |
# | 804 | None | 44 |
# | 805 | None | 10 |
# | 806 | None | 98 |
# | 807 | None | 2090 |
# | 808 | None | 26 |
# | 809 | None | 225 |
# | 810 | None | 1853 |
# | 814 | None | 131 |
# | 815 | None | 724 |
# | 816 | None | 43 |
# | 817 | None | 660 |
# | 819 | None | 44 |
# | 820 | None | 753 |
# | 821 | None | 491 |
# | 822 | None | 52 |
# | 823 | None | 352 |
# | 824 | None | 272 |
# | 828 | None | 138 |
# | 832 | None | 117 |
# | 834 | None | 1401 |
# | 835 | None | 2851 |
# | 836 | None | 1068 |
# | 837 | None | 2378 |
# | 838 | None | 460 |
# | 839 | None | 64 |
# | 841 | None | 99 |
# | 842 | None | 100 |
# | 843 | None | 588 |
# | 845 | None | 279 |
# | 847 | None | 4964 |
# | 849 | None | 111 |
# | 851 | None | 20 |
# | 854 | None | 236 |
# | 855 | None | 625 |
# | 856 | None | 27 |
# | 858 | None | 173 |
# | 860 | None | 57 |
# | 861 | None | 490 |
# | 862 | None | 32 |
# | 863 | None | 65 |
# | 865 | None | 540 |
# | 867 | None | 92 |
# | 869 | None | 101 |
# | 870 | None | 70 |
# | 871 | None | 62 |
# | 872 | None | 155 |
# | 873 | None | 1064 |
# | 874 | None | 1478 |
# | 875 | None | 276 |
# | 877 | None | 101 |
# | 878 | None | 109 |
# | 879 | None | 14 |
# | 883 | None | 18 |
# | 884 | None | 3 |
# | 885 | None | 560 |
# | 886 | None | 5 |
# | 887 | None | 342 |
# | 888 | None | 6 |
# | 889 | None | 23 |
# | 890 | None | 293 |
# | 892 | None | 929 |
# | 893 | None | 276 |
# | 894 | None | 132 |
# | 895 | None | 884 |
# | 897 | None | 35 |
# | 898 | None | 37 |
# | 899 | None | 1631 |
# | 960 | None | 91 |
# | 980 | None | 1539 |
#
# ## Variable: AREA_RES
#
# - **Etiqueta**: Área de residencia habitual de la madre
# - **Preguntas del Cuestionario**:
#   Área de residencia habitual de la madre<br><br>1 = Cabecera municipal    <br>2 = Centro poblado (inspección, corregimiento o caserío)                                                                     <br>3 = Rural disperso   <br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | " | None | 7250 |
# | 1 | Cabecera municipal | 378914 |
# | 2 | Centro poblado (inspección, corregimiento o caserío) | 34980 |
# | 3 | Rural disperso | 94405 |
# | 9 | Sin información | 0 |
#
# ## Variable: N_HIJOSV
#
# - **Etiqueta**: Número de hijos nacidos vivos que ha tenido la madre, incluido el presente
# - **Preguntas del Cuestionario**:
#   Número de hijos nacidos vivos que ha tenido la madre, incluido el presente<br><br> 1 = 1 hijo<br> 2 = 2 hijos<br> 3 = 3 hijos<br> 4 = 4 hijos<br> 5 = 5 hijos<br> 6 = 6 hijos<br> 7 = 7 hijos<br> 8 = 8 hijos<br> 9 = 9 hijos<br> 10 = 10 hijos<br> 11 = 11 hijos<br> 12 = 12 hijos<br> 13 = 13 hijos<br> 14 = 14 hijos<br> 15 = 15 hijos<br> 16 = 16 hijos <br> 17 = 17 hijos<br> 18 = 18 hijos<br> 19 = 19 hijos<br> 20 = 20 hijos<br> 21 = 21 hijos<br> 22 = 22 hijos<br> 99 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | 1 hijo | 235780 |
# | 2 | 2 hijos | 168493 |
# | 3 | 3 hijos | 67521 |
# | 4 | 4 hijos | 21940 |
# | 5 | 5 hijos | 8808 |
# | 6 | 6 hijos | 4342 |
# | 7 | 7 hijos | 2096 |
# | 8 | 8 hijos | 1053 |
# | 9 | 9 hijos | 562 |
# | 10 | 10 hijos | 250 |
# | 11 | 11 hijos | 111 |
# | 12 | 12 hijos | 66 |
# | 13 | 13 hijos | 28 |
# | 14 | 14 hijos | 8 |
# | 15 | 15 hijos | 4 |
# | 16 | 16 hijos | 1 |
# | 17 | 17 hijos | 1 |
# | 18 | 18 hijos | 0 |
# | 19 | 19 hijos | 0 |
# | 20 | 20 hijos | 0 |
# | 21 | 21 hijos | 0 |
# | 22 | 22 hijos | 0 |
# | 99 | Sin información | 4485 |
#
# ## Variable: FECHA_NACM
#
# - **Etiqueta**: Fecha de nacimiento del anterior hijo nacido vivo
# - **Preguntas del Cuestionario**:
#   Fecha de nacimiento del anterior hijo nacido vivo
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | NA     | NA       | NA         |
#
# ## Variable: N_EMB
#
# - **Etiqueta**: Número de embarazos, incluido el presente
# - **Preguntas del Cuestionario**:
#   Número de embarazos, incluido el presente<br><br>99 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 99 | Sin información | 4491 |
#
# ## Variable: SEG_SOCIAL
#
# - **Etiqueta**: Régimen de seguridad social en salud de la madre
# - **Preguntas del Cuestionario**:
#   Régimen de seguridad social en salud de la madre<br><br>1 = Contributivo            <br>2 = Subsidiado<br>3 = Excepción <br>4 = Especial <br>5 = No asegurado<br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Contributivo | 191858 |
# | 2 | Subsidiado | 290602 |
# | 3 | Excepción | 4864 |
# | 4 | Especial | 102 |
# | 5 | No asegurado | 23638 |
# | 9 | Sin información | 4485 |
#
# ## Variable: IDCLASADMI
#
# - **Etiqueta**: Entidad Administradora en Salud a la que pertenece la madre
# - **Preguntas del Cuestionario**:
#   Entidad Administradora en Salud a la que pertenece la madre<br><br>1 = Entidad promotora de salud                   <br>2 = Entidad promotora de salud - Subsidiado                                                          <br>3 = Entidad adaptada de salud     <br>4 = Entidad especial de salud  <br>5 = Entidad exceptuada de salud       <br>9 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | " | None | 23638 |
# | 1 | Entidad promotora de salud | 191858 |
# | 2 | Entidad promotora de salud - Subsidiado | 290602 |
# | 3 | Entidad adaptada de salud | 0 |
# | 4 | Entidad especial de salud | 102 |
# | 5 | Entidad exceptuada de salud | 4864 |
# | 9 | Sin información | 4485 |
#
# ## Variable: EDAD_PADRE
#
# - **Etiqueta**: Edad del padre en años cumplidos a la fecha del nacimiento de este hijo
# - **Preguntas del Cuestionario**:
#   Edad del padre en años cumplidos a la fecha del nacimiento de este hijo<br><br>999 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 999 | Sin información | 6282 |
#
# ## Variable: ULTCURPAD
#
# - **Etiqueta**: Ultimo año o grado aprobado del padre
# - **Preguntas del Cuestionario**:
#   Último año o grado aprobado del nivel educativo del padre<br><br>99 = Sin información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 99 | Sin información | 48515 |
#
# ## Variable: PROFESION
#
# - **Etiqueta**: Profesión de quien certifica el nacimiento
# - **Preguntas del Cuestionario**:
#   Profesión de quien certifica el nacimiento<br><br>1 = Médico<br>2 = Enfermero(a) <br>3 = Auxiliar de enfermería<br>4 = Promotor(a) de salud  <br>5 = Funcionario de registro civil<br>9= Sin Información
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | " | None | 4485 |
# | 1 | Médico | 508666 |
# | 2 | Enfermero(a) | 258 |
# | 3 | Auxiliar de enfermería | 806 |
# | 4 | Promotor(a) de salud | 235 |
# | 5 | Funcionario de registro civil | 1099 |
#
# ## Variable: TIPOFORMULARIO
#
# - **Etiqueta**: Fuente del Certificado
# - **Preguntas del Cuestionario**:
#   Tipo de formulario para la captura de información<br><br>1 = Certificado RUAF-ND<br>2 = Formato de Notificación Étnica<br>3 = Recuperación cruce RNEC
#
# ### Tabla de Categorías:
# | Código | Etiqueta | Frecuencia |
# |--------|----------|------------|
# | 1 | Certificado RUAF-ND | 511063 |
# | 2 | Formato de Notificación Étnica | 400 |
# | 3 | Recuperación cruce RNEC | 4086 |
